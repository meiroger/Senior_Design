# %%
import simpy
from random import seed, random, expovariate, normalvariate, triangular
import numpy as np
import pandas as pd
import math

# %% [markdown]
# # Ambulance

# %%
def ambulance_driver(env, name, ambulance_resource, ambulance_arrival_duration):
    with ambulance_resource.request() as req:
        yield req
        # Ambulance Contact and Arrival
        #print('%s Ambulance pre-calling contact at %d' % (name, env.now))
        yield env.timeout(ambulance_arrival_duration)
        #print('%s Ambulance arrived at %d' % (name, env.now))

# %% [markdown]
# ## Walkin Patients Process

# %%
def walkin_patient(env, name, arrival_time, routine_care, ambulance_resource, ICU_duration, triage_duration, ED_eval_duration, stroke_identified_percentage, routine_care_duration, CT_duration, HS_percentage, ambulance_arrival_duration, telestroke_duration, TPA_decision_percentage, TPA_consent_percentage, TPA_long_consent_percentage, TPA_consent_duration, TPA_mixing_duration, pharmacist_arrival_duration, CTA_decision_percentage, CTA_duration, transfer_decision_percentage):
    # Simulate patient arrivals to the PSC (door in)
    yield env.timeout(arrival_time)
    #print('%s walk in at %d' % (name, env.now))
    door_in = env.now
    
    # Triage
    #print('%s Triage start at %d' % (name, env.now))
    yield env.timeout(triage_duration)
    #print('%s Triage ended at %d' % (name, env.now))
    Triage_times.append(triage_duration)
    
    # ED Evaluation
    #print('%s ED Evaluation start at %d' % (name, env.now))
    yield env.timeout(ED_eval_duration)
    #print('%s ED Evaluation ended at %d' % (name, env.now))
    ED_eval_times.append(ED_eval_duration)
    
    # Stroke identified? (90% yes, 10% no) if not (10%), then add extra time in routine care
    if random() > stroke_identified_percentage:
        with routine_care.request() as req:
            yield req
            #print('%s Routine Care at %d' % (name, env.now))
            yield env.timeout(routine_care_duration)
            #print('%s Routine Care ended at %d' % (name, env.now))
            routine_care_times.append(routine_care_duration)
    
    #### Stroke Code Activation ###
    early_send = 0
    if random() < early_send_1_percentage:
        early_send = 1
        # Wait for Ambulance
        with ambulance_resource.request() as req:
                yield req
                #print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                #print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                #print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                #print('%s Ambulance arrived at %d' % (name, env.now))
                Ambulance_times.append(ambulance_arrival_duration)
    
    ####### EARLY SEND 1 ########
    if early_send != 1:
        # CT Scan
        #print('%s CT scan at %d' % (name, env.now))
        yield env.timeout(CT_duration)
        #print('%s CT scan ended at %d' % (name, env.now))
        CT_scan_times.append(CT_duration)

        # HSvIS (15% HS)
        if random() < HS_percentage: 
            # Hemorrhagic stroke -> Ambulance Contact, Ambulance Arrival, CSC
            with ambulance_resource.request() as req:
                yield req
                #print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                #print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                #print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                # HS DIDO times
                hs_DIDO_times.append(door_out - door_in)
                #print('%s Ambulance arrived at %d' % (name, env.now))
                Ambulance_times.append(ambulance_arrival_duration)

        # Ischemic Stroke 
        else:
            # Ischemic stroke (85%)
            # Telestroke
            #print('%s Telestroke at %d' % (name, env.now))
            yield env.timeout(telestroke_duration)
            #print('%s Telestroke ended at %d' % (name, env.now))
            Telestroke_times.append(telestroke_duration)
            
            if random() < early_send_2_percentage:
                early_send = 2
                with ambulance_resource.request() as req:
                    yield req
                    #print('%s Patient gets on ambulance at %d' % (name, env.now))
                    yield env.timeout(1)
                    # CSC (door out)
                    #print('%s Patient send to CSC at %d' % (name, env.now))
                    door_out = env.now
                    #print('%s DIDO:' % name, door_out - door_in)
                    DIDO_times.append(door_out - door_in)
                    # IS DIDO times
                    is_DIDO_times.append(door_out - door_in)
                    #print('%s Ambulance arrived at %d' % (name, env.now))
                    Ambulance_times.append(ambulance_arrival_duration)
                
            ####### EARLY SEND 2 ########
            if early_send != 2:
                # TPA (5% gets TPA)
                consent = 0
                if random() < TPA_decision_percentage:
                    # (90% consent)
                    if random() <  TPA_consent_percentage:
                        consent = 1
                        # TPA long consent duration (90%, 10% don't take time)
                        if random() < TPA_long_consent_percentage:
                            #print('%s TPA consent at %d' % (name, env.now))
                            yield env.timeout(TPA_consent_duration)
                            #print('%s TPA consent ended at %d' % (name, env.now))
                            Long_Consent_times.append(TPA_consent_duration)

                        # pharmacist in ED or not? yes if between 8am and 6pm
                        if ((env.now%1440)/60 > 8 and (env.now%1440)/60 < 18):
                            #print('%s TPA mixing at %d' % (name, env.now))
                            yield env.timeout(TPA_mixing_duration)
                            #print('%s TPA mixing ended and injection at %d' % (name, env.now))
                            Mix_TPA_times.append(TPA_mixing_duration)
                            # door to needle time
                            door_to_needle.append(env.now - door_in)
                        else:
                            #print('%s TPA mixing at %d' % (name, env.now))
                            yield env.timeout(TPA_mixing_duration + pharmacist_arrival_duration)
                            #print('%s TPA mixing ended and injection at %d' % (name, env.now))
                            Mix_TPA_times.append(TPA_mixing_duration)
                            Pharmacist_Arrival_times.append(pharmacist_arrival_duration)
                            # door to needle time
                            door_to_needle.append(env.now - door_in)
                    else: # (10% don't consent)
                        consent = 0
                        # Ambulance Contact and Arrival
                        with ambulance_resource.request() as req:
                            yield req
                            #print('%s Patient gets on ambulance at %d' % (name, env.now))
                            yield env.timeout(1)
                            # CSC (door out)
                            #print('%s Patient send to CSC at %d' % (name, env.now))
                            door_out = env.now
                            #print('%s DIDO:' % name, door_out - door_in)
                            DIDO_times.append(door_out - door_in)
                            # IS DIDO times
                            is_DIDO_times.append(door_out - door_in)
                            #print('%s Ambulance arrived at %d' % (name, env.now))
                            Ambulance_times.append(ambulance_arrival_duration)

                if consent:
                    ####### EARLY SEND 3 ########
                    if random() < early_send_3_percentage:
                        early_send = 3
                        # Ambulance Contact and Arrival
                        with ambulance_resource.request() as req:
                            yield req
                            #print('%s Patient gets on ambulance at %d' % (name, env.now))
                            yield env.timeout(1)
                            # CSC (door out)
                            #print('%s Patient send to CSC at %d' % (name, env.now))
                            door_out = env.now
                            #print('%s DIDO:' % name, door_out - door_in)
                            DIDO_times.append(door_out - door_in)
                            # IS DIDO times
                            is_DIDO_times.append(door_out - door_in)
                            #print('%s Ambulance arrived at %d' % (name, env.now))
                            Ambulance_times.append(ambulance_arrival_duration)
                    
                    if early_send != 3:
                        # CTA decision (47% yes)
                        if random() < CTA_decision_percentage:
                            #print('%s CTA Scan at %d' % (name, env.now))
                            yield env.timeout(CTA_duration)
                            #print('%s CTA Scan ended at %d' % (name, env.now))
                            CTA_times.append(CTA_duration)

                        # transfer decision (15% yes)
                        if random() < transfer_decision_percentage:
                            # Ambulance Contact and Arrival
                            with ambulance_resource.request() as req:
                                yield req
                                #print('%s Patient gets on ambulance at %d' % (name, env.now))
                                yield env.timeout(1)
                                # CSC (door out)
                                #print('%s Patient send to CSC at %d' % (name, env.now))
                                door_out = env.now
                                #print('%s DIDO:' % name, door_out - door_in)
                                DIDO_times.append(door_out - door_in)
                                # IS DIDO times
                                is_DIDO_times.append(door_out - door_in)
                                #print('%s Ambulance arrived at %d' % (name, env.now))
                                Ambulance_times.append(ambulance_arrival_duration) 
                        else:
                            # ICU
                            door_out = env.now
                            #print('%s ICU out time:' % name, door_out - door_in)
                            #print('%s ICU at %d' % (name, env.now))
                            ICU_in = env.now
                            yield env.timeout(ICU_duration)
                            ICU_out = env.now
                            #print('%s ICU ended at %d' % (name, env.now))  
                            ICU_times.append(ICU_out - ICU_in)

# %% [markdown]
# ## EMS Patients Process

# %%
def EMS_patient(env, name, arrival_time, routine_care, ambulance_resource, ICU_duration, EMS_screen_percentage, triage_duration, ED_eval_duration, stroke_identified_percentage, routine_care_duration, CT_duration, HS_percentage, ambulance_arrival_duration, telestroke_duration, TPA_decision_percentage,  TPA_consent_percentage, TPA_long_consent_percentage, TPA_consent_duration, TPA_mixing_duration, pharmacist_arrival_duration, CTA_decision_percentage, CTA_duration, transfer_decision_percentage):
    # Simulate patient arrivals to the PSC (door in)
    yield env.timeout(arrival_time)
    #print('%s EMS arrival at %d' % (name, env.now))
    door_in = env.now
    
    # EMS screened as stroke? (83% yes, 17% no) if EMS didn't screen as stroke, then add triage, ed evaluation[, and maybe routine care]
    if random() > EMS_screen_percentage:
        # Triage
        #print('%s Triage start at %d' % (name, env.now))
        yield env.timeout(triage_duration)
        #print('%s Triage ended at %d' % (name, env.now))
        Triage_times.append(triage_duration)

        # ED Evaluation
        #print('%s ED Evaluation start at %d' % (name, env.now))
        yield env.timeout(ED_eval_duration)
        #print('%s ED Evaluation ended at %d' % (name, env.now))
        ED_eval_times.append(ED_eval_duration)

        # Stroke identified? (90% yes, 10% no) if not, then add extra time in routine care
        if random() > stroke_identified_percentage:
            with routine_care.request() as req:
                yield req
                #print('%s Routine Care at %d' % (name, env.now))
                yield env.timeout(routine_care_duration)
                #print('%s Routine Care ended at %d' % (name, env.now))
                routine_care_times.append(routine_care_duration)
        
    #### Stroke Code Activation ###
    early_send = 0
    if random() < early_send_1_percentage:
        early_send = 1
        # Wait for Ambulance
        with ambulance_resource.request() as req:
                yield req
                #print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                #print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                #print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                #print('%s Ambulance arrived at %d' % (name, env.now))
                Ambulance_times.append(ambulance_arrival_duration)
    
    ####### EARLY SEND 1 ########
    if early_send != 1:
        # CT Scan
        #print('%s CT scan at %d' % (name, env.now))
        yield env.timeout(CT_duration)
        #print('%s CT scan ended at %d' % (name, env.now))
        CT_scan_times.append(CT_duration)

        # HSvIS (15% HS)
        if random() < HS_percentage: 
            # Hemorrhagic stroke -> Ambulance Contact, Ambulance Arrival, CSC
            with ambulance_resource.request() as req:
                yield req
                #print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                #print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                #print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                # HS DIDO times
                hs_DIDO_times.append(door_out - door_in)
                #print('%s Ambulance arrived at %d' % (name, env.now))
                Ambulance_times.append(ambulance_arrival_duration)

        # Ischemic Stroke 
        else:
            # Ischemic stroke (85%)
            # Telestroke
            #print('%s Telestroke at %d' % (name, env.now))
            yield env.timeout(telestroke_duration)
            #print('%s Telestroke ended at %d' % (name, env.now))
            Telestroke_times.append(telestroke_duration)
            
            if random() < early_send_2_percentage:
                early_send = 2
                with ambulance_resource.request() as req:
                    yield req
                    #print('%s Patient gets on ambulance at %d' % (name, env.now))
                    yield env.timeout(1)
                    # CSC (door out)
                    #print('%s Patient send to CSC at %d' % (name, env.now))
                    door_out = env.now
                    #print('%s DIDO:' % name, door_out - door_in)
                    DIDO_times.append(door_out - door_in)
                    # IS DIDO times
                    is_DIDO_times.append(door_out - door_in)
                    #print('%s Ambulance arrived at %d' % (name, env.now))
                    Ambulance_times.append(ambulance_arrival_duration)
                
            ####### EARLY SEND 2 ########
            if early_send != 2:
                # TPA (5% gets TPA)
                consent = 0
                if random() < TPA_decision_percentage:
                    # (90% consent)
                    if random() <  TPA_consent_percentage:
                        consent = 1
                        # TPA long consent duration (90%, 10% don't take time)
                        if random() < TPA_long_consent_percentage:
                            #print('%s TPA consent at %d' % (name, env.now))
                            yield env.timeout(TPA_consent_duration)
                            #print('%s TPA consent ended at %d' % (name, env.now))
                            Long_Consent_times.append(TPA_consent_duration)

                        # pharmacist in ED or not? yes if between 8am and 6pm
                        if ((env.now%1440)/60 > 8 and (env.now%1440)/60 < 18):
                            #print('%s TPA mixing at %d' % (name, env.now))
                            yield env.timeout(TPA_mixing_duration)
                            #print('%s TPA mixing ended and injection at %d' % (name, env.now))
                            Mix_TPA_times.append(TPA_mixing_duration)
                            # door to needle time
                            door_to_needle.append(env.now - door_in)
                        else:
                            #print('%s TPA mixing at %d' % (name, env.now))
                            yield env.timeout(TPA_mixing_duration + pharmacist_arrival_duration)
                            #print('%s TPA mixing ended and injection at %d' % (name, env.now))
                            Mix_TPA_times.append(TPA_mixing_duration)
                            Pharmacist_Arrival_times.append(pharmacist_arrival_duration)
                            # door to needle time
                            door_to_needle.append(env.now - door_in)
                    else: # (10% don't consent)
                        consent = 0
                        # Ambulance Contact and Arrival
                        with ambulance_resource.request() as req:
                            yield req
                            #print('%s Patient gets on ambulance at %d' % (name, env.now))
                            yield env.timeout(1)
                            # CSC (door out)
                            #print('%s Patient send to CSC at %d' % (name, env.now))
                            door_out = env.now
                            #print('%s DIDO:' % name, door_out - door_in)
                            DIDO_times.append(door_out - door_in)
                            # IS DIDO times
                            is_DIDO_times.append(door_out - door_in)
                            #print('%s Ambulance arrived at %d' % (name, env.now))
                            Ambulance_times.append(ambulance_arrival_duration)

                if consent:
                    ####### EARLY SEND 3 ########
                    if random() < early_send_3_percentage:
                        early_send = 3
                        # Ambulance Contact and Arrival
                        with ambulance_resource.request() as req:
                            yield req
                            #print('%s Patient gets on ambulance at %d' % (name, env.now))
                            yield env.timeout(1)
                            # CSC (door out)
                            #print('%s Patient send to CSC at %d' % (name, env.now))
                            door_out = env.now
                            #print('%s DIDO:' % name, door_out - door_in)
                            DIDO_times.append(door_out - door_in)
                            # IS DIDO times
                            is_DIDO_times.append(door_out - door_in)
                            #print('%s Ambulance arrived at %d' % (name, env.now))
                            Ambulance_times.append(ambulance_arrival_duration)
                    
                    if early_send != 3:
                        # CTA decision (47% yes)
                        if random() < CTA_decision_percentage:
                            #print('%s CTA Scan at %d' % (name, env.now))
                            yield env.timeout(CTA_duration)
                            #print('%s CTA Scan ended at %d' % (name, env.now))
                            CTA_times.append(CTA_duration)

                        # transfer decision (15% yes)
                        if random() < transfer_decision_percentage:
                            # Ambulance Contact and Arrival
                            with ambulance_resource.request() as req:
                                yield req
                                #print('%s Patient gets on ambulance at %d' % (name, env.now))
                                yield env.timeout(1)
                                # CSC (door out)
                                #print('%s Patient send to CSC at %d' % (name, env.now))
                                door_out = env.now
                                #print('%s DIDO:' % name, door_out - door_in)
                                DIDO_times.append(door_out - door_in)
                                # IS DIDO times
                                is_DIDO_times.append(door_out - door_in)
                                #print('%s Ambulance arrived at %d' % (name, env.now))
                                Ambulance_times.append(ambulance_arrival_duration) 
                        else:
                            # ICU
                            door_out = env.now
                            #print('%s ICU out time:' % name, door_out - door_in)
                            #print('%s ICU at %d' % (name, env.now))
                            ICU_in = env.now
                            yield env.timeout(ICU_duration)
                            ICU_out = env.now
                            #print('%s ICU ended at %d' % (name, env.now))  
                            ICU_times.append(ICU_out - ICU_in)

# %% [markdown]
# # General ED Patients Process

# %%
def ED_patient(env, name, arrival_time, routine_care_duration):
    yield env.timeout(arrival_time)
    with routine_care.request() as req:
        yield req
#         print('%s Routine Care at %d' % (name, env.now))
        yield env.timeout(routine_care_duration)
#         print('%s Routine Care ended at %d' % (name, env.now))

# %% [markdown]
# ## Data Input

# %%
path = './'
data = pd.read_csv(path + 'simulation_data.csv')
print('Previewing simulation data...')
data
# Out:
# Previewing simulation data...
#                          process   count  mean(mins)  triangular  percentage  \
# 0                   arrival_rate     NaN     2160.00         NaN         NaN
# 1                   ICU_duration     NaN       60.00         NaN         NaN
# 2        EMS_arrivals_percentage     NaN         NaN         NaN        0.70
# 3          EMS_screen_percentage     NaN         NaN         NaN        0.83
# 4                triage_duration     NaN        6.00         NaN         NaN
# 5               ED_eval_duration     NaN        7.80         NaN         NaN
# 6   stroke_identified_percentage     NaN         NaN         NaN        0.90
# 7          routine_care_duration     NaN       90.00         NaN         NaN
# 8                    CT_duration     NaN       28.33         NaN         NaN
# 9                  HS_percentage     NaN         NaN         NaN        0.15
# 10    ambulance_arrival_duration     NaN       20.00         NaN         NaN
# 11           telestroke_duration     NaN       30.00         NaN         NaN
# 12       TPA_decision_percentage     NaN         NaN         NaN        0.05
# 13        TPA_consent_percentage     NaN         NaN         NaN        0.90
# 14   TPA_long_consent_percentage     NaN         NaN         NaN        0.90
# 15          TPA_consent_duration     NaN       30.00         NaN         NaN
# 16           TPA_mixing_duration     NaN         NaN  10,12.5,15         NaN
# 17   pharmacist_arrival_duration     NaN         NaN   2.5,5,7.5         NaN
# 18       CTA_decision_percentage     NaN         NaN         NaN        0.47
# 19                  CTA_duration     NaN       40.00         NaN         NaN
# 20  transfer_decision_percentage     NaN         NaN         NaN        0.15
# 21       early_send_1_percentage     NaN         NaN         NaN        0.10
# 22       early_send_2_percentage     NaN         NaN         NaN        0.10
# 23       early_send_3_percentage     NaN         NaN         NaN        0.10
# 24           num_stroke_patients  2000.0         NaN         NaN         NaN
# 25         routine_care_capacity    10.0         NaN         NaN         NaN
#
#    distribution/type                                              Notes
# 0            poisson             1.5 days on average per stroke patient
# 1        exponential                                                NaN
# 2         percentage        percentage of arrivals by EMS (not walk-in)
# 3         percentage                                                NaN
# 4        exponential                                                NaN
# 5        exponential                                                NaN
# 6         percentage                                                NaN
# 7        exponential                                                NaN
# 8        exponential                                                NaN
# 9         percentage                                                NaN
# 10       exponential                                                NaN
# 11       exponential                                                NaN
# 12        percentage                                                NaN
# 13        percentage                            90% of patients consent
# 14        percentage             90% of patients take longer to consent
# 15       exponential                           duration of long consent
# 16        triangular                                                NaN
# 17        triangular                                                NaN
# 18        percentage                                                NaN
# 19       exponential                                                NaN
# 20        percentage                                                NaN
# 21        percentage  percent chance of sending early at early send ...
# 22        percentage  percent chance of sending early at early send ...
# 23        percentage  percent chance of sending early at early send ...
# 24             count  total number of stroke patients to be simulate...
# 25             count  capacity/number of servers (beds/rooms) for ro...

# %%
# ED arrival data for routine care
ED_arrival_data = pd.read_excel('./LFH ED arrival rate 2019.xlsx')
print('Previewing ED arrival data...')
print(ED_arrival_data.head())

# counting arrivals by date
ED_arrival_counts = {}
for index,row in ED_arrival_data.iterrows():
    month = str(row['Arrival Date/Time'].month)
    day = str(row['Arrival Date/Time'].day)
    hour = str(row['Arrival Date/Time'].hour)
    date_key = month + '-' + day + '-' + hour
    if date_key not in ED_arrival_counts.keys():
        ED_arrival_counts[date_key] = 1
    else:
        ED_arrival_counts[date_key] += 1

# organizing counts by hour
import re
pattern = '.+-.+-(.+)'
ED_hour_counts = {}
for key, value in ED_arrival_counts.items():
    hour = re.findall(pattern,key)[0]
    if hour not in ED_hour_counts.keys():
        ED_hour_counts[hour] = [value]
    else:
        ED_hour_counts[hour].append(value)
        
# average arrival rate per hour for general ED patient arrivals to routine care
avg_arrivals_per_hour = [0]*24
for key, value in ED_hour_counts.items():
    idx = int(key)
    avg_arrivals_per_hour[idx] = np.mean(value)
# arrival rates in minutes for each hour
time_varying = [60/arrival for arrival in avg_arrivals_per_hour]
# Out:
# Previewing ED arrival data...
#     Arrival Date/Time  Month  Year Site
# 0 2019-01-01 01:56:00      1  2019  LFH
# 1 2019-01-01 05:21:00      1  2019  LFH
# 2 2019-01-01 07:35:00      1  2019  LFH
# 3 2019-01-01 10:36:00      1  2019  LFH
# 4 2019-01-01 11:56:00      1  2019  LFH

# %% [markdown]
# ## Simulation

# %%
results_df = pd.DataFrame(columns = ['DIDO', 'HS_DIDO', 'IS_DIDO', 'ICU_Times', 'Door-To-Needle', 'Triage', 'ED Eval', 
                                     'Routine Care', 'CT','Ambulance Arrival', 'Telestroke', 'Long Consent', 
                                     'Pharmacist Arrival', 'TPA Mixing', 'CTA'])
for j in range(200):
    early_send_1_percentage = data[data.process =='early_send_1_percentage']['percentage'].item()
    early_send_2_percentage = data[data.process =='early_send_2_percentage']['percentage'].item()
    early_send_3_percentage =data[data.process =='early_send_3_percentage']['percentage'].item()
#     seed(1)
    DIDO_times = []
    hs_DIDO_times = []
    is_DIDO_times = []
    ICU_times = []
    door_to_needle = []
    Triage_times = []
    ED_eval_times = []
    routine_care_times = []
    CT_scan_times = []
    Ambulance_times = []
    Telestroke_times = []
    Long_Consent_times = []
    Pharmacist_Arrival_times = []
    Mix_TPA_times = []
    CTA_times = []

    TPA_mixing_duration_triangular = [float(x) for x in data[data.process =='TPA_mixing_duration']['triangular'].item().split(',')]
    pharmacist_arrival_duration_triangular = [float(x) for x in data[data.process =='pharmacist_arrival_duration']['triangular'].item().split(',')]

    # define environment
    env = simpy.Environment()
    # define ICU capacity
    routine_care = simpy.Resource(env, capacity=int(data[data.process =='routine_care_capacity']['count']))
    # define total number of stroke patients
    num_patients = data[data.process =='num_stroke_patients']['count']
    # ambulance resources per patient
    ambulance_resources = []
    for i in range(int(num_patients)): 
        ambulance_resources.append(simpy.Resource(env, capacity=1))

    # general ED arrivals
    ED_arrival_time = 0
    for i in range(50*int(num_patients)):
        arrival_rate = np.random.poisson(time_varying[math.floor(ED_arrival_time%1440/60)])
        ED_arrival_time += arrival_rate
        routine_care_duration = expovariate(1/float(data[data.process =='routine_care_duration']['mean(mins)']))
        env.process(ED_patient(env,'ED_Patient %d' % i, ED_arrival_time, routine_care_duration))

    # EMS arrivals
    EMS_arrival_time = 0
    for i in range(int(float(data[data.process =='EMS_arrivals_percentage']['percentage'])*int(num_patients))):
        ICU_duration = expovariate(1/float(data[data.process =='ICU_duration']['mean(mins)']))
        EMS_screen_percentage = data[data.process =='EMS_screen_percentage']['percentage'].item()
        triage_duration = expovariate(1/float(data[data.process =='triage_duration']['mean(mins)']))
        ED_eval_duration = expovariate(1/float(data[data.process =='ED_eval_duration']['mean(mins)']))
        stroke_identified_percentage = data[data.process =='stroke_identified_percentage']['percentage'].item()
        routine_care_duration = expovariate(1/float(data[data.process =='routine_care_duration']['mean(mins)']))
        CT_duration = expovariate(1/float(data[data.process =='CT_duration']['mean(mins)']))
        HS_percentage = data[data.process =='HS_percentage']['percentage'].item()
        ambulance_arrival_duration = expovariate(1/float(data[data.process =='ambulance_arrival_duration']['mean(mins)']))
        telestroke_duration = expovariate(1/float(data[data.process =='telestroke_duration']['mean(mins)']))
        TPA_decision_percentage = data[data.process =='TPA_decision_percentage']['percentage'].item()
        TPA_consent_percentage = data[data.process =='TPA_consent_percentage']['percentage'].item()
        TPA_long_consent_percentage = data[data.process =='TPA_long_consent_percentage']['percentage'].item()
        TPA_consent_duration = expovariate(1/float(data[data.process =='TPA_consent_duration']['mean(mins)']))
        TPA_mixing_duration = triangular(TPA_mixing_duration_triangular[0],TPA_mixing_duration_triangular[1],TPA_mixing_duration_triangular[2])
        pharmacist_arrival_duration = triangular(pharmacist_arrival_duration_triangular[0],pharmacist_arrival_duration_triangular[1],pharmacist_arrival_duration_triangular[2])
        CTA_decision_percentage = data[data.process =='CTA_decision_percentage']['percentage'].item()
        CTA_duration = expovariate(1/float(data[data.process =='CTA_duration']['mean(mins)']))
        transfer_decision_percentage = data[data.process =='transfer_decision_percentage']['percentage'].item()

        # arrival rate
        EMS_arrival_rate = np.random.poisson(float(data[data.process =='arrival_rate']['mean(mins)']))
        EMS_arrival_time += EMS_arrival_rate
        env.process(EMS_patient(env, 'EMS_Patient %d' % i, EMS_arrival_time, routine_care, ambulance_resources[i], ICU_duration, EMS_screen_percentage, triage_duration, ED_eval_duration, stroke_identified_percentage, routine_care_duration, CT_duration, HS_percentage, ambulance_arrival_duration, telestroke_duration, TPA_decision_percentage, TPA_consent_percentage, TPA_long_consent_percentage, TPA_consent_duration, TPA_mixing_duration, pharmacist_arrival_duration, CTA_decision_percentage, CTA_duration, transfer_decision_percentage))

    # Walkin arrivals
    walkin_arrival_time = 0
    for i in range(int(float(data[data.process =='EMS_arrivals_percentage']['percentage'])*int(num_patients)),int(num_patients)):
        ICU_duration = expovariate(1/float(data[data.process =='ICU_duration']['mean(mins)']))
        EMS_screen_percentage = data[data.process =='EMS_screen_percentage']['percentage'].item()
        triage_duration = expovariate(1/float(data[data.process =='triage_duration']['mean(mins)']))
        ED_eval_duration = expovariate(1/float(data[data.process =='ED_eval_duration']['mean(mins)']))
        stroke_identified_percentage = data[data.process =='stroke_identified_percentage']['percentage'].item()
        routine_care_duration = expovariate(1/float(data[data.process =='routine_care_duration']['mean(mins)']))
        CT_duration = expovariate(1/float(data[data.process =='CT_duration']['mean(mins)']))
        HS_percentage = data[data.process =='HS_percentage']['percentage'].item()
        ambulance_arrival_duration = expovariate(1/float(data[data.process =='ambulance_arrival_duration']['mean(mins)']))
        telestroke_duration = expovariate(1/float(data[data.process =='telestroke_duration']['mean(mins)']))
        TPA_decision_percentage = data[data.process =='TPA_decision_percentage']['percentage'].item()
        TPA_consent_percentage = data[data.process =='TPA_consent_percentage']['percentage'].item()
        TPA_long_consent_percentage = data[data.process =='TPA_long_consent_percentage']['percentage'].item()
        TPA_consent_duration = expovariate(1/float(data[data.process =='TPA_consent_duration']['mean(mins)']))
        TPA_mixing_duration = triangular(TPA_mixing_duration_triangular[0],TPA_mixing_duration_triangular[1],TPA_mixing_duration_triangular[2])
        pharmacist_arrival_duration = triangular(pharmacist_arrival_duration_triangular[0],pharmacist_arrival_duration_triangular[1],pharmacist_arrival_duration_triangular[2])
        CTA_decision_percentage = data[data.process =='CTA_decision_percentage']['percentage'].item()
        CTA_duration = expovariate(1/float(data[data.process =='CTA_duration']['mean(mins)']))
        transfer_decision_percentage = data[data.process =='transfer_decision_percentage']['percentage'].item()

        # arrival rate
        walkin_arrival_rate = np.random.poisson(float(data[data.process =='arrival_rate']['mean(mins)']))
        walkin_arrival_time += walkin_arrival_rate
        env.process(walkin_patient(env, 'walkin_Patient %d' % i, walkin_arrival_time, routine_care, ambulance_resources[i], ICU_duration, triage_duration, ED_eval_duration, stroke_identified_percentage, routine_care_duration, CT_duration, HS_percentage, ambulance_arrival_duration, telestroke_duration, TPA_decision_percentage, TPA_consent_percentage, TPA_long_consent_percentage, TPA_consent_duration, TPA_mixing_duration, pharmacist_arrival_duration, CTA_decision_percentage, CTA_duration, transfer_decision_percentage))

    env.run(until=3000*num_patients)
#     print("\nCSC number of patients sent:",len(DIDO_times),"(%d percent)" % (len(DIDO_times)/int(num_patients)*100))
#     print("Mean DIDO time:", np.mean(DIDO_times), "minutes")
#     if early_send == 0 or 2:
#         if early_send != 2 and early_send != 3:
#             print("ICU number of patients sent:",len(ICU_times),"(%d percent)" % (len(ICU_times)/int(num_patients)*100))
#             print("Mean ICU out time", np.mean(ICU_times), "minutes")
#         print("\nMean HS DIDO time:", np.mean(hs_DIDO_times), "minutes (%d patients)" % len(hs_DIDO_times))
    print("Mean IS DIDO time:", np.mean(is_DIDO_times), "minutes (%d patients)"% len(is_DIDO_times))
#         if early_send != 2:
#             print("Mean door-to-needle time:", np.mean(door_to_needle), "minutes (%d patients)"% len(door_to_needle))
    results =  [np.mean(DIDO_times), np.mean(hs_DIDO_times), np.mean(is_DIDO_times), np.mean(ICU_times), np.mean(door_to_needle),
                np.mean(Triage_times), np.mean(ED_eval_times), np.mean(routine_care_times), np.mean(CT_scan_times), 
                np.mean(Ambulance_times), np.mean(Telestroke_times), np.mean(Long_Consent_times), np.mean(Pharmacist_Arrival_times),
                np.mean(Mix_TPA_times), np.mean(CTA_times)]
    results_df.loc[j] = results
results_df.head()
# Out:
# walkin_Patient 1402 DIDO: 38.07862503397337
# EMS_Patient 4 DIDO: 1
# walkin_Patient 1407 DIDO: 13.841859468309849
# EMS_Patient 16 DIDO: 1
# EMS_Patient 18 DIDO: 1
# walkin_Patient 1422 DIDO: 15.664860238750407
# walkin_Patient 1424 DIDO: 22.338688596013526
# walkin_Patient 1425 DIDO: 6.018898878151958
# walkin_Patient 1430 DIDO: 135.92507893024595
# walkin_Patient 1437 DIDO: 26.905531990298186
# EMS_Patient 49 DIDO: 1
# EMS_Patient 53 DIDO: 1
# walkin_Patient 1464 DIDO: 22.258028836746234
# EMS_Patient 69 DIDO: 13.628926480392693
# EMS_Patient 70 DIDO: 15.682679418096086
# EMS_Patient 77 DIDO: 1
# EMS_Patient 86 DIDO: 1
# walkin_Patient 1501 DIDO: 40.69574390293565
# walkin_Patient 1502 DIDO: 7.587917035387363
# EMS_Patient 104 DIDO: 19.761948349914746
# EMS_Patient 107 DIDO: 1
# walkin_Patient 1508 DIDO: 16.735069758287864
# walkin_Patient 1515 DIDO: 10.14037031881162
# walkin_Patient 1523 DIDO: 9.666743317327928
# walkin_Patient 1526 DIDO: 9.15377839555731
# EMS_Patient 126 DIDO: 1
# walkin_Patient 1529 DIDO: 3.798260411072988
# EMS_Patient 138 DIDO: 1
# EMS_Patient 140 DIDO: 1
# EMS_Patient 147 DIDO: 1
# walkin_Patient 1554 DIDO: 21.09611729887547
# walkin_Patient 1558 DIDO: 16.15103291691048
# walkin_Patient 1569 DIDO: 8.713616188091692
# EMS_Patient 178 DIDO: 1
# walkin_Patient 1590 DIDO: 9.875209444609936
# walkin_Patient 1611 DIDO: 6.201657158904709
# walkin_Patient 1612 DIDO: 15.18904353841208
# walkin_Patient 1621 DIDO: 17.954542502993718
# walkin_Patient 1625 DIDO: 10.993961319269147
# walkin_Patient 1626 DIDO: 13.935058667091653
# walkin_Patient 1640 DIDO: 7.398392140341457
# EMS_Patient 244 DIDO: 4.516308430931531
# EMS_Patient 253 DIDO: 1
# EMS_Patient 256 DIDO: 17.218510575359687
# walkin_Patient 1659 DIDO: 58.36946439463645
# EMS_Patient 259 DIDO: 4.108816949068569
# walkin_Patient 1660 DIDO: 21.176095620612614
# walkin_Patient 1663 DIDO: 24.601768023567274
# EMS_Patient 269 DIDO: 1
# EMS_Patient 275 DIDO: 1
# EMS_Patient 278 DIDO: 1
# walkin_Patient 1684 DIDO: 13.91020991874393
# walkin_Patient 1689 DIDO: 9.245458046905696
# EMS_Patient 290 DIDO: 1
# walkin_Patient 1718 DIDO: 16.030078817042522
# walkin_Patient 1724 DIDO: 201.29039701318834
# walkin_Patient 1730 DIDO: 2.161991666071117
# EMS_Patient 333 DIDO: 9.042516409652308
# walkin_Patient 1745 DIDO: 23.561491776141338
# EMS_Patient 351 DIDO: 1
# walkin_Patient 1756 DIDO: 4.065286158467643
# walkin_Patient 1763 DIDO: 4.885701745166443
# EMS_Patient 370 DIDO: 1
# EMS_Patient 372 DIDO: 1
# walkin_Patient 1773 DIDO: 6.858710965607315
# walkin_Patient 1777 DIDO: 15.740568352630362
# walkin_Patient 1783 DIDO: 6.096024247352034
# walkin_Patient 1799 DIDO: 13.78042912564706
# EMS_Patient 406 DIDO: 1
# walkin_Patient 1807 DIDO: 22.600930879008956
# walkin_Patient 1809 DIDO: 8.946172229130752
# EMS_Patient 410 DIDO: 1
# walkin_Patient 1813 DIDO: 56.93808962730691
# EMS_Patient 417 DIDO: 1
# walkin_Patient 1822 DIDO: 11.663148065446876
# walkin_Patient 1823 DIDO: 17.972865680232644
# walkin_Patient 1833 DIDO: 43.11591855750885
# walkin_Patient 1835 DIDO: 16.937169984797947
# walkin_Patient 1841 DIDO: 13.154352401965298
# EMS_Patient 445 DIDO: 1
# EMS_Patient 446 DIDO: 16.395855069276877
# EMS_Patient 447 DIDO: 1
# EMS_Patient 453 DIDO: 22.64644922723528
# EMS_Patient 459 DIDO: 3.334850062034093
# walkin_Patient 1861 DIDO: 20.467756367987022
# walkin_Patient 1869 DIDO: 18.06045938655734
# EMS_Patient 470 DIDO: 1
# walkin_Patient 1873 DIDO: 18.46714066772256
# EMS_Patient 479 DIDO: 1
# EMS_Patient 486 DIDO: 1
# EMS_Patient 491 DIDO: 6.47398319747299
# EMS_Patient 492 DIDO: 1
# EMS_Patient 500 DIDO: 1
# walkin_Patient 1906 DIDO: 11.352890281006694
# walkin_Patient 1909 DIDO: 3.5931721860542893
# walkin_Patient 1915 DIDO: 2.2187351228203624
# EMS_Patient 524 DIDO: 1
# walkin_Patient 1927 DIDO: 17.230089524993673
# EMS_Patient 534 DIDO: 1
# walkin_Patient 1935 DIDO: 22.046301681315526
# EMS_Patient 535 DIDO: 1
# walkin_Patient 1947 DIDO: 3.595551113365218
# EMS_Patient 551 DIDO: 1
# walkin_Patient 1958 DIDO: 11.905254541197792
# EMS_Patient 559 DIDO: 7.58269411069341
# EMS_Patient 560 DIDO: 1
# walkin_Patient 1972 DIDO: 82.72402035654522
# EMS_Patient 572 DIDO: 1
# EMS_Patient 576 DIDO: 1
# EMS_Patient 589 DIDO: 1
# EMS_Patient 591 DIDO: 1
# walkin_Patient 1993 DIDO: 8.862564685987309
# EMS_Patient 610 DIDO: 1
# EMS_Patient 616 DIDO: 1
# EMS_Patient 634 DIDO: 1
# EMS_Patient 644 DIDO: 1
# EMS_Patient 654 DIDO: 1
# EMS_Patient 667 DIDO: 1
# EMS_Patient 676 DIDO: 1
# EMS_Patient 677 DIDO: 1
# EMS_Patient 687 DIDO: 1
# EMS_Patient 688 DIDO: 1
# EMS_Patient 694 DIDO: 1
# EMS_Patient 704 DIDO: 1
# EMS_Patient 706 DIDO: 1
# EMS_Patient 709 DIDO: 1
# EMS_Patient 740 DIDO: 1
# EMS_Patient 746 DIDO: 1
# EMS_Patient 753 DIDO: 33.4805453796871
# EMS_Patient 761 DIDO: 1
# EMS_Patient 774 DIDO: 1
# EMS_Patient 779 DIDO: 1
# EMS_Patient 780 DIDO: 1
# EMS_Patient 789 DIDO: 1
# EMS_Patient 801 DIDO: 1
# EMS_Patient 810 DIDO: 1
# EMS_Patient 811 DIDO: 1
# EMS_Patient 821 DIDO: 1
# EMS_Patient 828 DIDO: 1
# EMS_Patient 829 DIDO: 1
# EMS_Patient 841 DIDO: 1
# EMS_Patient 860 DIDO: 1
# EMS_Patient 866 DIDO: 1
# EMS_Patient 870 DIDO: 1
# EMS_Patient 885 DIDO: 1
# EMS_Patient 927 DIDO: 9.012510099913925
# EMS_Patient 935 DIDO: 292.87762925284915
# EMS_Patient 961 DIDO: 1
# EMS_Patient 964 DIDO: 1
# EMS_Patient 973 DIDO: 1
# EMS_Patient 987 DIDO: 1
# EMS_Patient 1001 DIDO: 1
# EMS_Patient 1020 DIDO: 1
# EMS_Patient 1042 DIDO: 1
# EMS_Patient 1049 DIDO: 1
# EMS_Patient 1076 DIDO: 1
# EMS_Patient 1090 DIDO: 12.334779983386397
# EMS_Patient 1093 DIDO: 1
# EMS_Patient 1095 DIDO: 1
# EMS_Patient 1103 DIDO: 1
# EMS_Patient 1114 DIDO: 1
# EMS_Patient 1116 DIDO: 1
# EMS_Patient 1133 DIDO: 1
# EMS_Patient 1149 DIDO: 1
# EMS_Patient 1150 DIDO: 1
# EMS_Patient 1152 DIDO: 1
# EMS_Patient 1157 DIDO: 1
# EMS_Patient 1161 DIDO: 18.417946382891387
# EMS_Patient 1168 DIDO: 1
# EMS_Patient 1188 DIDO: 1
# EMS_Patient 1191 DIDO: 1
# EMS_Patient 1226 DIDO: 1
# EMS_Patient 1232 DIDO: 1
# EMS_Patient 1236 DIDO: 1
# EMS_Patient 1281 DIDO: 1
# EMS_Patient 1290 DIDO: 1
# EMS_Patient 1302 DIDO: 1
# EMS_Patient 1307 DIDO: 1
# EMS_Patient 1315 DIDO: 10.230030107311904
# EMS_Patient 1335 DIDO: 1
# EMS_Patient 1353 DIDO: 1
# EMS_Patient 1361 DIDO: 1
# EMS_Patient 1379 DIDO: 1
# EMS_Patient 1391 DIDO: 26.386225156486034
# EMS_Patient 1399 DIDO: 1
# Mean IS DIDO time: 87.8116529956634 minutes (163 patients)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ac9cd7c4aff4> in <module>
#      42         arrival_rate = np.random.poisson(time_varying[math.floor(ED_arrival_time%1440/60)])
#      43         ED_arrival_time += arrival_rate
# ---> 44         routine_care_duration = expovariate(1/float(data[data.process =='routine_care_duration']['mean(mins)']))
#      45         env.process(ED_patient(env,'ED_Patient %d' % i, ED_arrival_time, routine_care_duration))
#      46
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_array(self, key)
#    2722             key = check_bool_indexer(self.index, key)
#    2723             indexer = key.nonzero()[0]
# -> 2724             return self._take(indexer, axis=0)
#    2725         else:
#    2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _take(self, indices, axis, is_copy)
#    2788                                    axis=self._get_block_manager_axis(axis),
#    2789                                    verify=True)
# -> 2790         result = self._constructor(new_data).__finalize__(self)
#    2791
#    2792         # Maybe set copy if we didn't actually change the index.
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _constructor(self)
#     318     """
#     319
# --> 320     @property
#     321     def _constructor(self):
#     322         return DataFrame
#
# KeyboardInterrupt:

# %%
import statsmodels.api as sm
distributions = ['Triage', 'ED Eval', 'Routine Care', 'CT','Ambulance Arrival', 'Telestroke', 'Long Consent', 
                 'Pharmacist Arrival', 'TPA Mixing', 'CTA']
outputs = ['DIDO', 'HS_DIDO', 'IS_DIDO', 'Door-To-Needle', 'ICU_Times']
results_df.dropna(axis=0, inplace=True)
sensitivity_df = pd.DataFrame(columns=distributions, index=outputs)
for o in outputs:
    model = sm.OLS(results_df[o], results_df[distributions]).fit()
    sensitivity_df.loc[o] = model.params
sensitivity_df

# %%
import matplotlib.pyplot as plt
output_toplot = 'Door-To-Needle'
plt.barh(np.arange(len(sensitivity_df.columns)), sensitivity_df.loc[output_toplot, :].values)
plt.yticks(np.arange(len(sensitivity_df.columns)), sensitivity_df.columns)
plt.title('Door to Needle Sensitivity')
plt.show()
# sensitivity_df.loc['DIDO', :].values

# %%
sensitivity_df.to_csv('sensitivity.csv')
