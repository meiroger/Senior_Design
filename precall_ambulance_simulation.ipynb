# %%
import simpy
from random import seed, random, expovariate, normalvariate, triangular
import numpy as np
import pandas as pd
import math
early_send = 0

# %% [markdown]
# # Ambulance

# %%
def ambulance_driver(env, name, ambulance_resource, ambulance_arrival_duration):
    with ambulance_resource.request() as req:
        yield req
        # Ambulance Contact and Arrival
        print('%s Ambulance pre-calling contact at %d' % (name, env.now))
        yield env.timeout(ambulance_arrival_duration)
        print('%s Ambulance arrived at %d' % (name, env.now))

# %% [markdown]
# ## Walkin Patients Process

# %%
def walkin_patient(env, name, arrival_time, routine_care, ambulance_resource, ICU_duration, triage_duration, ED_eval_duration, stroke_identified_percentage, routine_care_duration, CT_duration, HS_percentage, ambulance_arrival_duration, telestroke_duration, TPA_decision_percentage, TPA_consent_percentage, TPA_long_consent_percentage, TPA_consent_duration, TPA_mixing_duration, pharmacist_arrival_duration, CTA_decision_percentage, CTA_duration, transfer_decision_percentage):
    # Simulate patient arrivals to the PSC (door in)
    yield env.timeout(arrival_time)
    print('%s walk in at %d' % (name, env.now))
    door_in = env.now
    
    # Triage
    print('%s Triage start at %d' % (name, env.now))
    yield env.timeout(triage_duration)
    print('%s Triage ended at %d' % (name, env.now))
    
    # ED Evaluation
    print('%s ED Evaluation start at %d' % (name, env.now))
    yield env.timeout(ED_eval_duration)
    print('%s ED Evaluation ended at %d' % (name, env.now))
    
    # Stroke identified? (90% yes, 10% no) if not (10%), then add extra time in routine care
    if random() > stroke_identified_percentage:
        with routine_care.request() as req:
            yield req
            print('%s Routine Care at %d' % (name, env.now))
            yield env.timeout(routine_care_duration)
            print('%s Routine Care ended at %d' % (name, env.now))
    
    # Stroke Code Activation
    
    # early send at node 1 (after stroke code activation)
    if early_send == 1:
        # Ambulance Contact and Arrival
        print('%s Ambulance contact at %d' % (name, env.now))
        yield env.timeout(ambulance_arrival_duration)
        print('%s Ambulance arrived at %d' % (name, env.now))
        # CSC (door out)
        print('%s Patient send to CSC at %d' % (name, env.now))
        door_out = env.now
        print('%s DIDO:' % name, door_out - door_in)
        DIDO_times.append(door_out - door_in)
        
    # no early send
    elif early_send == 0:
        # CT Scan
        print('%s CT scan at %d' % (name, env.now))
        yield env.timeout(CT_duration)
        print('%s CT scan ended at %d' % (name, env.now))
        
        # HSvIS (15% HS)
        if random() < HS_percentage: 
            # Hemorrhagic stroke -> Ambulance Contact, Ambulance Arrival, CSC
            # Ambulance Contact and Arrival
            print('%s Ambulance contact at %d' % (name, env.now))
            yield env.timeout(ambulance_arrival_duration)
            print('%s Ambulance arrived at %d' % (name, env.now))

            # CSC (door out)
            print('%s Patient send to CSC at %d' % (name, env.now))
            door_out = env.now
            print('%s DIDO:' % name, door_out - door_in)
            DIDO_times.append(door_out - door_in)
            # HS DIDO times
            hs_DIDO_times.append(door_out - door_in)  
        # Ischemic Stroke 
        else:
            # Ischemic stroke (85%)
            # Telestroke
            print('%s Telestroke at %d' % (name, env.now))
            yield env.timeout(telestroke_duration)
            print('%s Telestroke ended at %d' % (name, env.now))
            # pre-call ambulance
            env.process(ambulance_driver(env, name, ambulance_resource, ambulance_arrival_duration))

            # TPA (5% gets TPA)
            if random() < TPA_decision_percentage:
                if random() <  TPA_consent_percentage:
                    # TPA long consent duration (90%, 10% don't take time)
                    if random() < TPA_long_consent_percentage:
                        print('%s TPA consent at %d' % (name, env.now))
                        yield env.timeout(TPA_consent_duration)
                        print('%s TPA consent ended at %d' % (name, env.now))

                    # pharmacist in ED or not? yes if between 8am and 6pm
                    if ((env.now%1440)/60 > 8 and (env.now%1440)/60 < 18):
                        print('%s TPA mixing at %d' % (name, env.now))
                        yield env.timeout(TPA_mixing_duration)
                        print('%s TPA mixing ended and injection at %d' % (name, env.now))
                        # door to needle time
                        door_to_needle.append(env.now - door_in)
                    else:
                        print('%s TPA mixing at %d' % (name, env.now))
                        yield env.timeout(TPA_mixing_duration + pharmacist_arrival_duration)
                        print('%s TPA mixing ended and injection at %d' % (name, env.now))
                        # door to needle time
                        door_to_needle.append(env.now - door_in)
                    
                    # CTA decision (47% yes)
                    CTA = 0
                    if random() < CTA_decision_percentage:
                        CTA = 1
                        print('%s CTA Scan at %d' % (name, env.now))
                        yield env.timeout(CTA_duration)
                        print('%s CTA Scan ended at %d' % (name, env.now))

                    # transfer decision (15% yes)
                    if random() < transfer_decision_percentage:
                        if CTA:
                            # Ambulance Contact and Arrival
                            print('%s Ambulance contact at %d' % (name, env.now))
                            yield env.timeout(ambulance_arrival_duration)
                            print('%s Ambulance arrived at %d' % (name, env.now))

                        # CSC (door out)
                        print('%s Patient send to CSC at %d' % (name, env.now))
                        door_out = env.now
                        print('%s DIDO:' % name, door_out - door_in)
                        DIDO_times.append(door_out - door_in)
                        # IS DIDO times
                        is_DIDO_times.append(door_out - door_in) 
                    else:
                        # ICU
                        door_out = env.now
                        print('%s ICU out time:' % name, door_out - door_in)
                        print('%s ICU at %d' % (name, env.now))
                        ICU_in = env.now
                        yield env.timeout(ICU_duration)
                        ICU_out = env.now
                        print('%s ICU ended at %d' % (name, env.now))  
                        ICU_times.append(ICU_out - ICU_in) 

                else: # (10% don't consent)
                    # Ambulance Contact and Arrival
                    print('%s Ambulance contact at %d' % (name, env.now))
                    yield env.timeout(ambulance_arrival_duration)
                    print('%s Ambulance arrived at %d' % (name, env.now))

                    # CSC (door out)
                    print('%s Patient send to CSC at %d' % (name, env.now))
                    door_out = env.now
                    print('%s DIDO:' % name, door_out - door_in)
                    DIDO_times.append(door_out - door_in)
                
    # early send at node 2 (after telestroke)            
    elif early_send == 2:
        # CT Scan
        print('%s CT scan at %d' % (name, env.now))
        yield env.timeout(CT_duration)
        print('%s CT scan ended at %d' % (name, env.now))
        
        # HSvIS (15% HS)
        if random() < HS_percentage: 
            # Hemorrhagic stroke -> Ambulance Contact, Ambulance Arrival, CSC
            # Ambulance Contact and Arrival
            print('%s Ambulance contact at %d' % (name, env.now))
            yield env.timeout(ambulance_arrival_duration)
            print('%s Ambulance arrived at %d' % (name, env.now))

            # CSC (door out)
            print('%s Patient send to CSC at %d' % (name, env.now))
            door_out = env.now
            print('%s DIDO:' % name, door_out - door_in)
            DIDO_times.append(door_out - door_in)
            # HS DIDO times
            hs_DIDO_times.append(door_out - door_in) 
        # Ischemic Stroke 
        else:
            # Ischemic stroke (85%)
            # Telestroke
            print('%s Telestroke at %d' % (name, env.now))
            yield env.timeout(telestroke_duration)
            print('%s Telestroke ended at %d' % (name, env.now))
            # pre-call ambulance
            env.process(ambulance_driver(env, name, ambulance_resource, ambulance_arrival_duration))

            # patient gets on ambulance
            with ambulance_resource.request() as req:
                yield req
                print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                # IS DIDO times
                is_DIDO_times.append(door_out - door_in)
            
    # early send at node 3 (after TPA)
    elif early_send == 3:
        # CT Scan
        print('%s CT scan at %d' % (name, env.now))
        yield env.timeout(CT_duration)
        print('%s CT scan ended at %d' % (name, env.now))
        
        # HSvIS (15% HS)
        if random() < HS_percentage: 
            # Hemorrhagic stroke -> Ambulance Contact, Ambulance Arrival, CSC
            # Ambulance Contact and Arrival
            print('%s Ambulance contact at %d' % (name, env.now))
            yield env.timeout(ambulance_arrival_duration)
            print('%s Ambulance arrived at %d' % (name, env.now))

            # CSC (door out)
            print('%s Patient send to CSC at %d' % (name, env.now))
            door_out = env.now
            print('%s DIDO:' % name, door_out - door_in)
            DIDO_times.append(door_out - door_in)
            # HS DIDO times
            hs_DIDO_times.append(door_out - door_in) 
        # Ischemic Stroke 
        else:
            # Ischemic stroke (85%)
            # Telestroke
            print('%s Telestroke at %d' % (name, env.now))
            yield env.timeout(telestroke_duration)
            print('%s Telestroke ended at %d' % (name, env.now))
            # pre-call ambulance
            env.process(ambulance_driver(env, name, ambulance_resource, ambulance_arrival_duration))

            # TPA (5% gets TPA)
            if random() < TPA_decision_percentage:
                if random() <  TPA_consent_percentage:
                    # TPA long consent duration (90%, 10% don't take time)
                    if random() < TPA_long_consent_percentage:
                        print('%s TPA consent at %d' % (name, env.now))
                        yield env.timeout(TPA_consent_duration)
                        print('%s TPA consent ended at %d' % (name, env.now))

                    # pharmacist in ED or not? yes if between 8am and 6pm
                    if ((env.now%1440)/60 > 8 and (env.now%1440)/60 < 18):
                        print('%s TPA mixing at %d' % (name, env.now))
                        yield env.timeout(TPA_mixing_duration)
                        print('%s TPA mixing ended and injection at %d' % (name, env.now))
                        # door to needle time
                        door_to_needle.append(env.now - door_in)
                    else:
                        print('%s TPA mixing at %d' % (name, env.now))
                        yield env.timeout(TPA_mixing_duration + pharmacist_arrival_duration)
                        print('%s TPA mixing ended and injection at %d' % (name, env.now))
                        # door to needle time
                        door_to_needle.append(env.now - door_in)

            # patient gets on ambulance
            with ambulance_resource.request() as req:
                yield req
                print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                # IS DIDO times
                is_DIDO_times.append(door_out - door_in)

# %% [markdown]
# ## EMS Patients Process

# %%
def EMS_patient(env, name, arrival_time, routine_care, ambulance_resource, ICU_duration, EMS_screen_percentage, triage_duration, ED_eval_duration, stroke_identified_percentage, routine_care_duration, CT_duration, HS_percentage, ambulance_arrival_duration, telestroke_duration, TPA_decision_percentage, TPA_consent_percentage, TPA_long_consent_percentage, TPA_consent_duration, TPA_mixing_duration, pharmacist_arrival_duration, CTA_decision_percentage, CTA_duration, transfer_decision_percentage):
    # Simulate patient arrivals to the PSC (door in)
    yield env.timeout(arrival_time)
    print('%s EMS arrival at %d' % (name, env.now))
    door_in = env.now
    
    # EMS screened as stroke? (83% yes, 17% no) if EMS didn't screen as stroke, then add triage, ed evaluation[, and maybe routine care]
    if random() > EMS_screen_percentage:
        # Triage
        print('%s Triage start at %d' % (name, env.now))
        yield env.timeout(triage_duration)
        print('%s Triage ended at %d' % (name, env.now))

        # ED Evaluation
        print('%s ED Evaluation start at %d' % (name, env.now))
        yield env.timeout(ED_eval_duration)
        print('%s ED Evaluation ended at %d' % (name, env.now))

        # Stroke identified? (90% yes, 10% no) if not, then add extra time in routine care
        if random() > stroke_identified_percentage:
            with routine_care.request() as req:
                yield req
                print('%s Routine Care at %d' % (name, env.now))
                yield env.timeout(routine_care_duration)
                print('%s Routine Care ended at %d' % (name, env.now))
        
    # Stroke Code Activation
    
    # early send at node 1 (after stroke code activation)
    if early_send == 1:
        # Ambulance Contact and Arrival
        print('%s Ambulance contact at %d' % (name, env.now))
        yield env.timeout(ambulance_arrival_duration)
        print('%s Ambulance arrived at %d' % (name, env.now))
        # CSC (door out)
        print('%s Patient send to CSC at %d' % (name, env.now))
        door_out = env.now
        print('%s DIDO:' % name, door_out - door_in)
        DIDO_times.append(door_out - door_in)
        
    # no early send
    elif early_send == 0:
        # CT Scan
        print('%s CT scan at %d' % (name, env.now))
        yield env.timeout(CT_duration)
        print('%s CT scan ended at %d' % (name, env.now))
        
        # HSvIS (15% HS)
        if random() < HS_percentage: 
            # Hemorrhagic stroke -> Ambulance Contact, Ambulance Arrival, CSC
            # patient gets on ambulance
            with ambulance_resource.request() as req:
                yield req
                print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                # HS DIDO times
                hs_DIDO_times.append(door_out - door_in) 
        else:
            # Ischemic stroke (85%)
            # Telestroke
            print('%s Telestroke at %d' % (name, env.now))
            yield env.timeout(telestroke_duration)
            print('%s Telestroke ended at %d' % (name, env.now))
            # pre-call ambulance
            env.process(ambulance_driver(env, name, ambulance_resource, ambulance_arrival_duration))

            # TPA (5% gets TPA)
            if random() < TPA_decision_percentage:
                if random() <  TPA_consent_percentage:
                    # TPA long consent duration (90%, 10% don't take time)
                    if random() < TPA_long_consent_percentage:
                        print('%s TPA consent at %d' % (name, env.now))
                        yield env.timeout(TPA_consent_duration)
                        print('%s TPA consent ended at %d' % (name, env.now))

                    # pharmacist in ED or not? yes if between 8am and 6pm
                    if ((env.now%1440)/60 > 8 and (env.now%1440)/60 < 18):
                        print('%s TPA mixing at %d' % (name, env.now))
                        yield env.timeout(TPA_mixing_duration)
                        print('%s TPA mixing ended and injection at %d' % (name, env.now))
                        # door to needle time
                        door_to_needle.append(env.now - door_in)
                    else:
                        print('%s TPA mixing at %d' % (name, env.now))
                        yield env.timeout(TPA_mixing_duration + pharmacist_arrival_duration)
                        print('%s TPA mixing ended and injection at %d' % (name, env.now))
                        # door to needle time
                        door_to_needle.append(env.now - door_in)
                    
                    # CTA decision (47% yes)
                    CTA = 0
                    if random() < CTA_decision_percentage:
                        CTA = 1
                        print('%s CTA Scan at %d' % (name, env.now))
                        yield env.timeout(CTA_duration)
                        print('%s CTA Scan ended at %d' % (name, env.now))

                    # transfer decision (15% yes)
                    if random() < transfer_decision_percentage:
                        if CTA:
                            # Ambulance Contact and Arrival
                            print('%s Ambulance contact at %d' % (name, env.now))
                            yield env.timeout(ambulance_arrival_duration)
                            print('%s Ambulance arrived at %d' % (name, env.now))

                        # CSC (door out)
                        print('%s Patient send to CSC at %d' % (name, env.now))
                        door_out = env.now
                        print('%s DIDO:' % name, door_out - door_in)
                        DIDO_times.append(door_out - door_in)
                        # IS DIDO times
                        is_DIDO_times.append(door_out - door_in) 
                    else:
                        # ICU
                        door_out = env.now
                        print('%s ICU out time:' % name, door_out - door_in)
                        print('%s ICU at %d' % (name, env.now))
                        ICU_in = env.now
                        yield env.timeout(ICU_duration)
                        ICU_out = env.now
                        print('%s ICU ended at %d' % (name, env.now))  
                        ICU_times.append(ICU_out - ICU_in) 

                else: # (10% don't consent)
                    # Ambulance Contact and Arrival
                    print('%s Ambulance contact at %d' % (name, env.now))
                    yield env.timeout(ambulance_arrival_duration)
                    print('%s Ambulance arrived at %d' % (name, env.now))

                    # CSC (door out)
                    print('%s Patient send to CSC at %d' % (name, env.now))
                    door_out = env.now
                    print('%s DIDO:' % name, door_out - door_in)
                    DIDO_times.append(door_out - door_in)
    
    # early send at node 2 (after telestroke)
    elif early_send == 2:
        # CT Scan
        print('%s CT scan at %d' % (name, env.now))
        yield env.timeout(CT_duration)
        print('%s CT scan ended at %d' % (name, env.now))
        
        # HSvIS (15% HS)
        if random() < HS_percentage: 
            # Hemorrhagic stroke -> Ambulance Contact, Ambulance Arrival, CSC
            # Ambulance Contact and Arrival
            print('%s Ambulance contact at %d' % (name, env.now))
            yield env.timeout(ambulance_arrival_duration)
            print('%s Ambulance arrived at %d' % (name, env.now))

            # CSC (door out)
            print('%s Patient send to CSC at %d' % (name, env.now))
            door_out = env.now
            print('%s DIDO:' % name, door_out - door_in)
            DIDO_times.append(door_out - door_in)
            # HS DIDO times
            hs_DIDO_times.append(door_out - door_in)  
        else:
            # Ischemic stroke (85%)
            # Telestroke
            print('%s Telestroke at %d' % (name, env.now))
            yield env.timeout(telestroke_duration)
            print('%s Telestroke ended at %d' % (name, env.now))
            # pre-call ambulance
            env.process(ambulance_driver(env, name, ambulance_resource, ambulance_arrival_duration))

            # patient gets on ambulance
            with ambulance_resource.request() as req:
                yield req
                print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                # IS DIDO times
                is_DIDO_times.append(door_out - door_in)
            
    # early send at node 3 (after telestroke)
    elif early_send == 3:
        # CT Scan
        print('%s CT scan at %d' % (name, env.now))
        yield env.timeout(CT_duration)
        print('%s CT scan ended at %d' % (name, env.now))
        
        # HSvIS (15% HS)
        if random() < HS_percentage: 
            # Hemorrhagic stroke -> Ambulance Contact, Ambulance Arrival, CSC
            # Ambulance Contact and Arrival
            print('%s Ambulance contact at %d' % (name, env.now))
            yield env.timeout(ambulance_arrival_duration)
            print('%s Ambulance arrived at %d' % (name, env.now))

            # CSC (door out)
            print('%s Patient send to CSC at %d' % (name, env.now))
            door_out = env.now
            print('%s DIDO:' % name, door_out - door_in)
            DIDO_times.append(door_out - door_in)
            # HS DIDO times
            hs_DIDO_times.append(door_out - door_in) 
        else:
            # Ischemic stroke (85%)
            # Telestroke
            print('%s Telestroke at %d' % (name, env.now))
            yield env.timeout(telestroke_duration)
            print('%s Telestroke ended at %d' % (name, env.now))
            # pre-call ambulance
            env.process(ambulance_driver(env, name, ambulance_resource, ambulance_arrival_duration))

            # TPA (5% gets TPA)
            if random() < TPA_decision_percentage:
                if random() <  TPA_consent_percentage:
                    # TPA long consent duration (90%, 10% don't take time)
                    if random() < TPA_long_consent_percentage:
                        print('%s TPA consent at %d' % (name, env.now))
                        yield env.timeout(TPA_consent_duration)
                        print('%s TPA consent ended at %d' % (name, env.now))

                    # pharmacist in ED or not? yes if between 8am and 6pm
                    if ((env.now%1440)/60 > 8 and (env.now%1440)/60 < 18):
                        print('%s TPA mixing at %d' % (name, env.now))
                        yield env.timeout(TPA_mixing_duration)
                        print('%s TPA mixing ended and injection at %d' % (name, env.now))
                        # door to needle time
                        door_to_needle.append(env.now - door_in)
                    else:
                        print('%s TPA mixing at %d' % (name, env.now))
                        yield env.timeout(TPA_mixing_duration + pharmacist_arrival_duration)
                        print('%s TPA mixing ended and injection at %d' % (name, env.now))
                        # door to needle time
                        door_to_needle.append(env.now - door_in)

            # patient gets on ambulance
            with ambulance_resource.request() as req:
                yield req
                print('%s Patient gets on ambulance at %d' % (name, env.now))
                yield env.timeout(1)
                # CSC (door out)
                print('%s Patient send to CSC at %d' % (name, env.now))
                door_out = env.now
                print('%s DIDO:' % name, door_out - door_in)
                DIDO_times.append(door_out - door_in)
                # IS DIDO times
                is_DIDO_times.append(door_out - door_in)

# %% [markdown]
# # General ED Patients Process

# %%
def ED_patient(env, name, arrival_time, routine_care_duration):
    yield env.timeout(arrival_time)
    with routine_care.request() as req:
        yield req
        print('%s Routine Care at %d' % (name, env.now))
        yield env.timeout(routine_care_duration)
        print('%s Routine Care ended at %d' % (name, env.now))

# %% [markdown]
# ## Data Input

# %%
path = './'
data = pd.read_csv(path + 'simulation_data.csv')
print('Previewing simulation data...')
data
# Out:
# Previewing simulation data...
#                          process  count  mean(mins)  triangular  percentage  \
# 0                   arrival_rate    NaN     2160.00         NaN         NaN
# 1                   ICU_duration    NaN       60.00         NaN         NaN
# 2        EMS_arrivals_percentage    NaN         NaN         NaN        0.70
# 3          EMS_screen_percentage    NaN         NaN         NaN        0.83
# 4                triage_duration    NaN        6.00         NaN         NaN
# 5               ED_eval_duration    NaN        7.80         NaN         NaN
# 6   stroke_identified_percentage    NaN         NaN         NaN        0.90
# 7          routine_care_duration    NaN       90.00         NaN         NaN
# 8                    CT_duration    NaN       28.33         NaN         NaN
# 9                  HS_percentage    NaN         NaN         NaN        0.15
# 10    ambulance_arrival_duration    NaN       20.00         NaN         NaN
# 11           telestroke_duration    NaN       30.00         NaN         NaN
# 12       TPA_decision_percentage    NaN         NaN         NaN        0.05
# 13        TPA_consent_percentage    NaN         NaN         NaN        0.90
# 14   TPA_long_consent_percentage    NaN         NaN         NaN        0.90
# 15          TPA_consent_duration    NaN       30.00         NaN         NaN
# 16           TPA_mixing_duration    NaN         NaN  10,12.5,15         NaN
# 17   pharmacist_arrival_duration    NaN         NaN   2.5,5,7.5         NaN
# 18       CTA_decision_percentage    NaN         NaN         NaN        0.47
# 19                  CTA_duration    NaN       40.00         NaN         NaN
# 20  transfer_decision_percentage    NaN         NaN         NaN        0.15
# 21           num_stroke_patients  100.0         NaN         NaN         NaN
# 22         routine_care_capacity   10.0         NaN         NaN         NaN
#
#    distribution/type                                              Notes
# 0            poisson             1.5 days on average per stroke patient
# 1        exponential                                                NaN
# 2         percentage        percentage of arrivals by EMS (not walk-in)
# 3         percentage                                                NaN
# 4        exponential                                                NaN
# 5        exponential                                                NaN
# 6         percentage                                                NaN
# 7        exponential                                                NaN
# 8        exponential                                                NaN
# 9         percentage                                                NaN
# 10       exponential                                                NaN
# 11       exponential                                                NaN
# 12        percentage                                                NaN
# 13        percentage                            90% of patients consent
# 14        percentage             90% of patients take longer to consent
# 15       exponential                           duration of long consent
# 16        triangular                                                NaN
# 17        triangular                                                NaN
# 18        percentage                                                NaN
# 19       exponential                                                NaN
# 20        percentage                                                NaN
# 21             count  total number of stroke patients to be simulate...
# 22             count  capacity/number of servers (beds/rooms) for ro...

# %%
# ED arrival data for routine care
ED_arrival_data = pd.read_excel('./LFH ED arrival rate 2019.xlsx')
print('Previewing ED arrival data...')
print(ED_arrival_data.head())

# counting arrivals by date
ED_arrival_counts = {}
for index,row in ED_arrival_data.iterrows():
    month = str(row['Arrival Date/Time'].month)
    day = str(row['Arrival Date/Time'].day)
    hour = str(row['Arrival Date/Time'].hour)
    date_key = month + '-' + day + '-' + hour
    if date_key not in ED_arrival_counts.keys():
        ED_arrival_counts[date_key] = 1
    else:
        ED_arrival_counts[date_key] += 1

# organizing counts by hour
import re
pattern = '.+-.+-(.+)'
ED_hour_counts = {}
for key, value in ED_arrival_counts.items():
    hour = re.findall(pattern,key)[0]
    if hour not in ED_hour_counts.keys():
        ED_hour_counts[hour] = [value]
    else:
        ED_hour_counts[hour].append(value)
        
# average arrival rate per hour for general ED patient arrivals to routine care
avg_arrivals_per_hour = [0]*24
for key, value in ED_hour_counts.items():
    idx = int(key)
    avg_arrivals_per_hour[idx] = np.mean(value)
# arrival rates in minutes for each hour
time_varying = [60/arrival for arrival in avg_arrivals_per_hour]
# Out:
# Previewing ED arrival data...
#     Arrival Date/Time  Month  Year Site
# 0 2019-01-01 01:56:00      1  2019  LFH
# 1 2019-01-01 05:21:00      1  2019  LFH
# 2 2019-01-01 07:35:00      1  2019  LFH
# 3 2019-01-01 10:36:00      1  2019  LFH
# 4 2019-01-01 11:56:00      1  2019  LFH

# %% [markdown]
# ## Simulation

# %%
early_send = int(input('Send early to CSC? (Please enter node number to send early at (1,2,3))\nOr enter 0 for no early sending '))
seed(333555)
DIDO_times = []
hs_DIDO_times = []
is_DIDO_times = []
ICU_times = []
door_to_needle = []

TPA_mixing_duration_triangular = [float(x) for x in data[data.process =='TPA_mixing_duration']['triangular'].item().split(',')]
pharmacist_arrival_duration_triangular = [float(x) for x in data[data.process =='pharmacist_arrival_duration']['triangular'].item().split(',')]

# define environment
env = simpy.Environment()
# define ICU capacity
routine_care = simpy.Resource(env, capacity=int(data[data.process =='routine_care_capacity']['count']))
# define total number of stroke patients
num_patients = data[data.process =='num_stroke_patients']['count']
# ambulance resources per patient
ambulance_resources = []
for i in range(int(num_patients)): 
    ambulance_resources.append(simpy.Resource(env, capacity=1))

# general ED arrivals
ED_arrival_time = 0
for i in range(100):
    arrival_rate = np.random.poisson(time_varying[math.floor(ED_arrival_time%1440/60)])
    ED_arrival_time += arrival_rate
    routine_care_duration = expovariate(1/float(data[data.process =='routine_care_duration']['mean(mins)']))
    env.process(ED_patient(env,'ED_Patient %d' % i, ED_arrival_time, routine_care_duration))

# EMS arrivals
EMS_arrival_time = 0
for i in range(int(float(data[data.process =='EMS_arrivals_percentage']['percentage'])*int(num_patients))):
    ICU_duration = expovariate(1/float(data[data.process =='ICU_duration']['mean(mins)']))
    EMS_screen_percentage = data[data.process =='EMS_screen_percentage']['percentage'].item()
    triage_duration = expovariate(1/float(data[data.process =='triage_duration']['mean(mins)']))
    ED_eval_duration = expovariate(1/float(data[data.process =='ED_eval_duration']['mean(mins)']))
    stroke_identified_percentage = data[data.process =='stroke_identified_percentage']['percentage'].item()
    routine_care_duration = expovariate(1/float(data[data.process =='routine_care_duration']['mean(mins)']))
    CT_duration = expovariate(1/float(data[data.process =='CT_duration']['mean(mins)']))
    HS_percentage = data[data.process =='HS_percentage']['percentage'].item()
    ambulance_arrival_duration = expovariate(1/float(data[data.process =='ambulance_arrival_duration']['mean(mins)']))
    telestroke_duration = expovariate(1/float(data[data.process =='telestroke_duration']['mean(mins)']))
    TPA_decision_percentage = data[data.process =='TPA_decision_percentage']['percentage'].item()
    TPA_consent_percentage = data[data.process =='TPA_consent_percentage']['percentage'].item()
    TPA_long_consent_percentage = data[data.process =='TPA_long_consent_percentage']['percentage'].item()
    TPA_consent_duration = expovariate(1/float(data[data.process =='TPA_consent_duration']['mean(mins)']))
    TPA_mixing_duration = triangular(TPA_mixing_duration_triangular[0],TPA_mixing_duration_triangular[1],TPA_mixing_duration_triangular[2])
    pharmacist_arrival_duration = triangular(pharmacist_arrival_duration_triangular[0],pharmacist_arrival_duration_triangular[1],pharmacist_arrival_duration_triangular[2])
    CTA_decision_percentage = data[data.process =='CTA_decision_percentage']['percentage'].item()
    CTA_duration = expovariate(1/float(data[data.process =='CTA_duration']['mean(mins)']))
    transfer_decision_percentage = data[data.process =='transfer_decision_percentage']['percentage'].item()
    
    # arrival rate
    EMS_arrival_rate = np.random.poisson(float(data[data.process =='arrival_rate']['mean(mins)']))
    EMS_arrival_time += EMS_arrival_rate
    env.process(EMS_patient(env, 'EMS_Patient %d' % i, EMS_arrival_time, routine_care, ambulance_resources[i], ICU_duration, EMS_screen_percentage, triage_duration, ED_eval_duration, stroke_identified_percentage, routine_care_duration, CT_duration, HS_percentage, ambulance_arrival_duration, telestroke_duration, TPA_decision_percentage, TPA_consent_percentage, TPA_long_consent_percentage, TPA_consent_duration, TPA_mixing_duration, pharmacist_arrival_duration, CTA_decision_percentage, CTA_duration, transfer_decision_percentage))

# Walkin arrivals
walkin_arrival_time = 0
for i in range(int(float(data[data.process =='EMS_arrivals_percentage']['percentage'])*int(num_patients)),int(num_patients)):
    ICU_duration = expovariate(1/float(data[data.process =='ICU_duration']['mean(mins)']))
    EMS_screen_percentage = data[data.process =='EMS_screen_percentage']['percentage'].item()
    triage_duration = expovariate(1/float(data[data.process =='triage_duration']['mean(mins)']))
    ED_eval_duration = expovariate(1/float(data[data.process =='ED_eval_duration']['mean(mins)']))
    stroke_identified_percentage = data[data.process =='stroke_identified_percentage']['percentage'].item()
    routine_care_duration = expovariate(1/float(data[data.process =='routine_care_duration']['mean(mins)']))
    CT_duration = expovariate(1/float(data[data.process =='CT_duration']['mean(mins)']))
    HS_percentage = data[data.process =='HS_percentage']['percentage'].item()
    ambulance_arrival_duration = expovariate(1/float(data[data.process =='ambulance_arrival_duration']['mean(mins)']))
    telestroke_duration = expovariate(1/float(data[data.process =='telestroke_duration']['mean(mins)']))
    TPA_decision_percentage = data[data.process =='TPA_decision_percentage']['percentage'].item()
    TPA_consent_percentage = data[data.process =='TPA_consent_percentage']['percentage'].item()
    TPA_long_consent_percentage = data[data.process =='TPA_long_consent_percentage']['percentage'].item()
    TPA_consent_duration = expovariate(1/float(data[data.process =='TPA_consent_duration']['mean(mins)']))
    TPA_mixing_duration = triangular(TPA_mixing_duration_triangular[0],TPA_mixing_duration_triangular[1],TPA_mixing_duration_triangular[2])
    pharmacist_arrival_duration = triangular(pharmacist_arrival_duration_triangular[0],pharmacist_arrival_duration_triangular[1],pharmacist_arrival_duration_triangular[2])
    CTA_decision_percentage = data[data.process =='CTA_decision_percentage']['percentage'].item()
    CTA_duration = expovariate(1/float(data[data.process =='CTA_duration']['mean(mins)']))
    transfer_decision_percentage = data[data.process =='transfer_decision_percentage']['percentage'].item()
    
    # arrival rate
    walkin_arrival_rate = np.random.poisson(float(data[data.process =='arrival_rate']['mean(mins)']))
    walkin_arrival_time += walkin_arrival_rate
    env.process(walkin_patient(env, 'walkin_Patient %d' % i, walkin_arrival_time, routine_care, ambulance_resources[i], ICU_duration, triage_duration, ED_eval_duration, stroke_identified_percentage, routine_care_duration, CT_duration, HS_percentage, ambulance_arrival_duration, telestroke_duration, TPA_decision_percentage, TPA_consent_percentage, TPA_long_consent_percentage, TPA_consent_duration, TPA_mixing_duration, pharmacist_arrival_duration, CTA_decision_percentage, CTA_duration, transfer_decision_percentage))
        
env.run(until=3000*num_patients)
print("\nCSC number of patients sent:",len(DIDO_times),"(%d percent)" % (len(DIDO_times)/int(num_patients)*100))
print("Mean DIDO time:", np.mean(DIDO_times), "minutes")
if early_send == 0 or early_send == 2:
    if early_send != 2 and early_send != 3:
        print("ICU number of patients sent:",len(ICU_times),"(%d percent)" % (len(ICU_times)/int(num_patients)*100))
        print("Mean ICU out time", np.mean(ICU_times), "minutes")
    print("\nMean HS DIDO time:", np.mean(hs_DIDO_times), "minutes (%d patients)" % len(hs_DIDO_times))
    print("Mean IS DIDO time:", np.mean(is_DIDO_times), "minutes (%d patients)"% len(is_DIDO_times))
    if early_send != 2:
        print("Mean door-to-needle time:", np.mean(door_to_needle), "minutes (%d patients)"% len(door_to_needle))
# Out:
# Send early to CSC? (Please enter node number to send early at (1,2,3))
# Or enter 0 for no early sending 0
# ED_Patient 0 Routine Care at 58
# ED_Patient 0 Routine Care ended at 81
# ED_Patient 1 Routine Care at 96
# ED_Patient 2 Routine Care at 146
# ED_Patient 2 Routine Care ended at 146
# ED_Patient 3 Routine Care at 199
# ED_Patient 4 Routine Care at 239
# ED_Patient 1 Routine Care ended at 240
# ED_Patient 5 Routine Care at 291
# ED_Patient 6 Routine Care at 352
# ED_Patient 3 Routine Care ended at 359
# ED_Patient 6 Routine Care ended at 398
# ED_Patient 7 Routine Care at 407
# ED_Patient 4 Routine Care ended at 423
# ED_Patient 8 Routine Care at 456
# ED_Patient 5 Routine Care ended at 465
# ED_Patient 8 Routine Care ended at 466
# ED_Patient 9 Routine Care at 508
# ED_Patient 9 Routine Care ended at 548
# ED_Patient 10 Routine Care at 549
# ED_Patient 11 Routine Care at 601
# ED_Patient 7 Routine Care ended at 615
# ED_Patient 10 Routine Care ended at 632
# ED_Patient 12 Routine Care at 646
# ED_Patient 12 Routine Care ended at 676
# ED_Patient 11 Routine Care ended at 678
# ED_Patient 13 Routine Care at 687
# ED_Patient 14 Routine Care at 740
# ED_Patient 14 Routine Care ended at 766
# ED_Patient 15 Routine Care at 797
# ED_Patient 15 Routine Care ended at 829
# ED_Patient 16 Routine Care at 846
# ED_Patient 17 Routine Care at 890
# ED_Patient 17 Routine Care ended at 894
# ED_Patient 18 Routine Care at 929
# ED_Patient 18 Routine Care ended at 931
# ED_Patient 16 Routine Care ended at 973
# ED_Patient 19 Routine Care at 977
# ED_Patient 19 Routine Care ended at 993
# ED_Patient 20 Routine Care at 1018
# ED_Patient 21 Routine Care at 1055
# ED_Patient 13 Routine Care ended at 1085
# ED_Patient 22 Routine Care at 1093
# ED_Patient 22 Routine Care ended at 1105
# ED_Patient 20 Routine Care ended at 1126
# ED_Patient 23 Routine Care at 1147
# ED_Patient 21 Routine Care ended at 1159
# ED_Patient 24 Routine Care at 1188
# ED_Patient 24 Routine Care ended at 1237
# ED_Patient 25 Routine Care at 1239
# ED_Patient 23 Routine Care ended at 1267
# ED_Patient 26 Routine Care at 1303
# ED_Patient 26 Routine Care ended at 1309
# ED_Patient 27 Routine Care at 1352
# ED_Patient 27 Routine Care ended at 1359
# ED_Patient 28 Routine Care at 1394
# ED_Patient 25 Routine Care ended at 1403
# ED_Patient 29 Routine Care at 1432
# ED_Patient 29 Routine Care ended at 1470
# ED_Patient 30 Routine Care at 1471
# ED_Patient 28 Routine Care ended at 1487
# ED_Patient 31 Routine Care at 1527
# ED_Patient 30 Routine Care ended at 1542
# ED_Patient 32 Routine Care at 1572
# ED_Patient 33 Routine Care at 1614
# ED_Patient 31 Routine Care ended at 1617
# ED_Patient 34 Routine Care at 1660
# ED_Patient 34 Routine Care ended at 1664
# ED_Patient 35 Routine Care at 1711
# ED_Patient 33 Routine Care ended at 1712
# ED_Patient 36 Routine Care at 1765
# ED_Patient 35 Routine Care ended at 1773
# ED_Patient 37 Routine Care at 1817
# ED_Patient 32 Routine Care ended at 1827
# ED_Patient 36 Routine Care ended at 1851
# ED_Patient 38 Routine Care at 1860
# ED_Patient 37 Routine Care ended at 1874
# ED_Patient 38 Routine Care ended at 1883
# ED_Patient 39 Routine Care at 1897
# ED_Patient 39 Routine Care ended at 1934
# ED_Patient 40 Routine Care at 1940
# ED_Patient 40 Routine Care ended at 1974
# ED_Patient 41 Routine Care at 1984
# ED_Patient 42 Routine Care at 2028
# ED_Patient 42 Routine Care ended at 2048
# ED_Patient 41 Routine Care ended at 2068
# ED_Patient 43 Routine Care at 2089
# ED_Patient 43 Routine Care ended at 2103
# ED_Patient 44 Routine Care at 2129
# EMS_Patient 0 EMS arrival at 2135
# EMS_Patient 0 CT scan at 2135
# EMS_Patient 0 CT scan ended at 2150
# EMS_Patient 0 Telestroke at 2150
# EMS_Patient 0 Telestroke ended at 2175
# EMS_Patient 0 Ambulance pre-calling contact at 2175
# ED_Patient 45 Routine Care at 2178
# EMS_Patient 0 Ambulance arrived at 2191
# walkin_Patient 70 walk in at 2202
# walkin_Patient 70 Triage start at 2202
# walkin_Patient 70 Triage ended at 2203
# walkin_Patient 70 ED Evaluation start at 2203
# ED_Patient 45 Routine Care ended at 2208
# walkin_Patient 70 ED Evaluation ended at 2216
# walkin_Patient 70 CT scan at 2216
# ED_Patient 46 Routine Care at 2218
# walkin_Patient 70 CT scan ended at 2222
# walkin_Patient 70 Ambulance contact at 2222
# walkin_Patient 70 Ambulance arrived at 2228
# walkin_Patient 70 Patient send to CSC at 2228
# walkin_Patient 70 DIDO: 26.37637938418311
# ED_Patient 47 Routine Care at 2267
# ED_Patient 47 Routine Care ended at 2284
# ED_Patient 44 Routine Care ended at 2303
# ED_Patient 48 Routine Care at 2326
# ED_Patient 48 Routine Care ended at 2356
# ED_Patient 49 Routine Care at 2359
# ED_Patient 49 Routine Care ended at 2368
# ED_Patient 50 Routine Care at 2408
# ED_Patient 50 Routine Care ended at 2443
# ED_Patient 51 Routine Care at 2454
# ED_Patient 51 Routine Care ended at 2460
# ED_Patient 52 Routine Care at 2493
# ED_Patient 52 Routine Care ended at 2505
# ED_Patient 53 Routine Care at 2534
# ED_Patient 46 Routine Care ended at 2548
# ED_Patient 53 Routine Care ended at 2567
# ED_Patient 54 Routine Care at 2585
# ED_Patient 55 Routine Care at 2637
# ED_Patient 54 Routine Care ended at 2663
# ED_Patient 56 Routine Care at 2691
# ED_Patient 55 Routine Care ended at 2701
# ED_Patient 57 Routine Care at 2738
# ED_Patient 57 Routine Care ended at 2753
# ED_Patient 58 Routine Care at 2791
# ED_Patient 59 Routine Care at 2831
# ED_Patient 59 Routine Care ended at 2862
# ED_Patient 56 Routine Care ended at 2869
# ED_Patient 60 Routine Care at 2873
# ED_Patient 61 Routine Care at 2915
# ED_Patient 61 Routine Care ended at 2928
# ED_Patient 60 Routine Care ended at 2947
# ED_Patient 62 Routine Care at 2967
# ED_Patient 58 Routine Care ended at 2987
# ED_Patient 63 Routine Care at 3022
# ED_Patient 62 Routine Care ended at 3030
# ED_Patient 63 Routine Care ended at 3053
# ED_Patient 64 Routine Care at 3068
# ED_Patient 65 Routine Care at 3116
# ED_Patient 64 Routine Care ended at 3151
# ED_Patient 66 Routine Care at 3158
# ED_Patient 65 Routine Care ended at 3164
# ED_Patient 67 Routine Care at 3214
# ED_Patient 68 Routine Care at 3268
# ED_Patient 68 Routine Care ended at 3282
# ED_Patient 66 Routine Care ended at 3290
# ED_Patient 69 Routine Care at 3325
# ED_Patient 69 Routine Care ended at 3355
# ED_Patient 70 Routine Care at 3372
# ED_Patient 67 Routine Care ended at 3412
# ED_Patient 71 Routine Care at 3418
# ED_Patient 71 Routine Care ended at 3431
# ED_Patient 70 Routine Care ended at 3433
# ED_Patient 72 Routine Care at 3452
# ED_Patient 73 Routine Care at 3517
# ED_Patient 73 Routine Care ended at 3557
# ED_Patient 74 Routine Care at 3560
# ED_Patient 72 Routine Care ended at 3569
# ED_Patient 75 Routine Care at 3621
# ED_Patient 74 Routine Care ended at 3643
# ED_Patient 75 Routine Care ended at 3655
# ED_Patient 76 Routine Care at 3672
# ED_Patient 77 Routine Care at 3720
# ED_Patient 78 Routine Care at 3762
# ED_Patient 76 Routine Care ended at 3775
# ED_Patient 78 Routine Care ended at 3781
# ED_Patient 77 Routine Care ended at 3807
# ED_Patient 79 Routine Care at 3808
# ED_Patient 80 Routine Care at 3870
# ED_Patient 80 Routine Care ended at 3870
# ED_Patient 79 Routine Care ended at 3878
# ED_Patient 81 Routine Care at 3915
# ED_Patient 81 Routine Care ended at 3935
# ED_Patient 82 Routine Care at 3958
# ED_Patient 83 Routine Care at 3997
# ED_Patient 83 Routine Care ended at 4031
# ED_Patient 82 Routine Care ended at 4035
# ED_Patient 84 Routine Care at 4036
# ED_Patient 85 Routine Care at 4077
# ED_Patient 84 Routine Care ended at 4094
# ED_Patient 86 Routine Care at 4115
# ED_Patient 85 Routine Care ended at 4131
# ED_Patient 87 Routine Care at 4159
# ED_Patient 87 Routine Care ended at 4162
# ED_Patient 88 Routine Care at 4202
# ED_Patient 86 Routine Care ended at 4214
# ED_Patient 88 Routine Care ended at 4222
# ED_Patient 89 Routine Care at 4256
# EMS_Patient 1 EMS arrival at 4269
# EMS_Patient 1 CT scan at 4269
# EMS_Patient 1 CT scan ended at 4288
# EMS_Patient 1 Telestroke at 4288
# ED_Patient 90 Routine Care at 4308
# ED_Patient 89 Routine Care ended at 4317
# EMS_Patient 1 Telestroke ended at 4319
# EMS_Patient 1 Ambulance pre-calling contact at 4319
# EMS_Patient 1 Ambulance arrived at 4323
# walkin_Patient 71 walk in at 4352
# walkin_Patient 71 Triage start at 4352
# walkin_Patient 71 Triage ended at 4352
# walkin_Patient 71 ED Evaluation start at 4352
# ED_Patient 91 Routine Care at 4355
# walkin_Patient 71 ED Evaluation ended at 4360
# walkin_Patient 71 CT scan at 4360
# ED_Patient 91 Routine Care ended at 4369
# walkin_Patient 71 CT scan ended at 4371
# walkin_Patient 71 Telestroke at 4371
# walkin_Patient 71 Telestroke ended at 4395
# walkin_Patient 71 Ambulance pre-calling contact at 4395
# walkin_Patient 71 Ambulance arrived at 4399
# ED_Patient 92 Routine Care at 4408
# ED_Patient 93 Routine Care at 4454
# ED_Patient 93 Routine Care ended at 4513
# ED_Patient 94 Routine Care at 4515
# ED_Patient 92 Routine Care ended at 4518
# ED_Patient 95 Routine Care at 4562
# ED_Patient 95 Routine Care ended at 4575
# ED_Patient 94 Routine Care ended at 4606
# ED_Patient 96 Routine Care at 4610
# ED_Patient 97 Routine Care at 4657
# ED_Patient 90 Routine Care ended at 4663
# ED_Patient 96 Routine Care ended at 4688
# ED_Patient 98 Routine Care at 4707
# ED_Patient 98 Routine Care ended at 4740
# ED_Patient 99 Routine Care at 4747
# ED_Patient 97 Routine Care ended at 4750
# ED_Patient 99 Routine Care ended at 4751
# EMS_Patient 2 EMS arrival at 6418
# EMS_Patient 2 CT scan at 6418
# EMS_Patient 2 CT scan ended at 6491
# EMS_Patient 2 Telestroke at 6491
# walkin_Patient 72 walk in at 6521
# walkin_Patient 72 Triage start at 6521
# walkin_Patient 72 Triage ended at 6526
# walkin_Patient 72 ED Evaluation start at 6526
# EMS_Patient 2 Telestroke ended at 6530
# EMS_Patient 2 Ambulance pre-calling contact at 6530
# EMS_Patient 2 Ambulance arrived at 6532
# walkin_Patient 72 ED Evaluation ended at 6552
# walkin_Patient 72 CT scan at 6552
# walkin_Patient 72 CT scan ended at 6552
# walkin_Patient 72 Telestroke at 6552
# walkin_Patient 72 Telestroke ended at 6701
# walkin_Patient 72 Ambulance pre-calling contact at 6701
# walkin_Patient 72 Ambulance arrived at 6705
# EMS_Patient 3 EMS arrival at 8524
# EMS_Patient 3 CT scan at 8524
# EMS_Patient 3 CT scan ended at 8549
# EMS_Patient 3 Telestroke at 8549
# EMS_Patient 3 Telestroke ended at 8568
# EMS_Patient 3 Ambulance pre-calling contact at 8568
# EMS_Patient 3 Ambulance arrived at 8576
# walkin_Patient 73 walk in at 8659
# walkin_Patient 73 Triage start at 8659
# walkin_Patient 73 Triage ended at 8659
# walkin_Patient 73 ED Evaluation start at 8659
# walkin_Patient 73 ED Evaluation ended at 8670
# walkin_Patient 73 CT scan at 8670
# walkin_Patient 73 CT scan ended at 8681
# walkin_Patient 73 Telestroke at 8681
# walkin_Patient 73 Telestroke ended at 8698
# walkin_Patient 73 Ambulance pre-calling contact at 8698
# walkin_Patient 73 Ambulance arrived at 8702
# EMS_Patient 4 EMS arrival at 10669
# EMS_Patient 4 Triage start at 10669
# EMS_Patient 4 Triage ended at 10674
# EMS_Patient 4 ED Evaluation start at 10674
# EMS_Patient 4 ED Evaluation ended at 10683
# EMS_Patient 4 CT scan at 10683
# EMS_Patient 4 CT scan ended at 10737
# EMS_Patient 4 Telestroke at 10737
# EMS_Patient 4 Telestroke ended at 10770
# EMS_Patient 4 Ambulance pre-calling contact at 10770
# EMS_Patient 4 Ambulance arrived at 10798
# walkin_Patient 74 walk in at 10851
# walkin_Patient 74 Triage start at 10851
# walkin_Patient 74 Triage ended at 10851
# walkin_Patient 74 ED Evaluation start at 10851
# walkin_Patient 74 ED Evaluation ended at 10854
# walkin_Patient 74 CT scan at 10854
# walkin_Patient 74 CT scan ended at 10884
# walkin_Patient 74 Telestroke at 10884
# walkin_Patient 74 Telestroke ended at 10905
# walkin_Patient 74 Ambulance pre-calling contact at 10905
# walkin_Patient 74 Ambulance arrived at 10927
# EMS_Patient 5 EMS arrival at 12892
# EMS_Patient 5 CT scan at 12892
# EMS_Patient 5 CT scan ended at 12899
# EMS_Patient 5 Telestroke at 12899
# EMS_Patient 5 Telestroke ended at 12939
# EMS_Patient 5 Ambulance pre-calling contact at 12939
# EMS_Patient 5 Ambulance arrived at 12944
# walkin_Patient 75 walk in at 13001
# walkin_Patient 75 Triage start at 13001
# walkin_Patient 75 Triage ended at 13001
# walkin_Patient 75 ED Evaluation start at 13001
# walkin_Patient 75 ED Evaluation ended at 13011
# walkin_Patient 75 CT scan at 13011
# walkin_Patient 75 CT scan ended at 13035
# walkin_Patient 75 Telestroke at 13035
# walkin_Patient 75 Telestroke ended at 13103
# walkin_Patient 75 Ambulance pre-calling contact at 13103
# walkin_Patient 75 Ambulance arrived at 13119
# EMS_Patient 6 EMS arrival at 15099
# EMS_Patient 6 CT scan at 15099
# EMS_Patient 6 CT scan ended at 15104
# EMS_Patient 6 Telestroke at 15104
# EMS_Patient 6 Telestroke ended at 15182
# EMS_Patient 6 Ambulance pre-calling contact at 15182
# EMS_Patient 6 Ambulance arrived at 15183
# walkin_Patient 76 walk in at 15212
# walkin_Patient 76 Triage start at 15212
# walkin_Patient 76 Triage ended at 15212
# walkin_Patient 76 ED Evaluation start at 15212
# walkin_Patient 76 ED Evaluation ended at 15214
# walkin_Patient 76 CT scan at 15214
# walkin_Patient 76 CT scan ended at 15229
# walkin_Patient 76 Telestroke at 15229
# walkin_Patient 76 Telestroke ended at 15256
# walkin_Patient 76 Ambulance pre-calling contact at 15256
# walkin_Patient 76 Ambulance arrived at 15280
# EMS_Patient 7 EMS arrival at 17287
# EMS_Patient 7 CT scan at 17287
# EMS_Patient 7 CT scan ended at 17303
# EMS_Patient 7 Patient gets on ambulance at 17303
# EMS_Patient 7 Patient send to CSC at 17304
# EMS_Patient 7 DIDO: 17.274916213089455
# walkin_Patient 77 walk in at 17358
# walkin_Patient 77 Triage start at 17358
# walkin_Patient 77 Triage ended at 17363
# walkin_Patient 77 ED Evaluation start at 17363
# walkin_Patient 77 ED Evaluation ended at 17368
# walkin_Patient 77 CT scan at 17368
# walkin_Patient 77 CT scan ended at 17385
# walkin_Patient 77 Telestroke at 17385
# walkin_Patient 77 Telestroke ended at 17427
# walkin_Patient 77 Ambulance pre-calling contact at 17427
# walkin_Patient 77 Ambulance arrived at 17445
# EMS_Patient 8 EMS arrival at 19386
# EMS_Patient 8 CT scan at 19386
# EMS_Patient 8 CT scan ended at 19493
# EMS_Patient 8 Telestroke at 19493
# walkin_Patient 78 walk in at 19506
# walkin_Patient 78 Triage start at 19506
# walkin_Patient 78 Triage ended at 19513
# walkin_Patient 78 ED Evaluation start at 19513
# walkin_Patient 78 ED Evaluation ended at 19520
# walkin_Patient 78 CT scan at 19520
# walkin_Patient 78 CT scan ended at 19526
# walkin_Patient 78 Telestroke at 19526
# walkin_Patient 78 Telestroke ended at 19554
# walkin_Patient 78 Ambulance pre-calling contact at 19554
# EMS_Patient 8 Telestroke ended at 19560
# EMS_Patient 8 Ambulance pre-calling contact at 19560
# EMS_Patient 8 Ambulance arrived at 19569
# walkin_Patient 78 Ambulance arrived at 19580
# EMS_Patient 9 EMS arrival at 21531
# EMS_Patient 9 CT scan at 21531
# EMS_Patient 9 CT scan ended at 21606
# EMS_Patient 9 Telestroke at 21606
# EMS_Patient 9 Telestroke ended at 21703
# EMS_Patient 9 Ambulance pre-calling contact at 21703
# walkin_Patient 79 walk in at 21717
# walkin_Patient 79 Triage start at 21717
# EMS_Patient 9 Ambulance arrived at 21719
# walkin_Patient 79 Triage ended at 21729
# walkin_Patient 79 ED Evaluation start at 21729
# walkin_Patient 79 ED Evaluation ended at 21731
# walkin_Patient 79 CT scan at 21731
# walkin_Patient 79 CT scan ended at 21807
# walkin_Patient 79 Telestroke at 21807
# walkin_Patient 79 Telestroke ended at 21817
# walkin_Patient 79 Ambulance pre-calling contact at 21817
# walkin_Patient 79 Ambulance arrived at 21821
# EMS_Patient 10 EMS arrival at 23786
# EMS_Patient 10 CT scan at 23786
# EMS_Patient 10 CT scan ended at 23797
# EMS_Patient 10 Telestroke at 23797
# EMS_Patient 10 Telestroke ended at 23835
# EMS_Patient 10 Ambulance pre-calling contact at 23835
# EMS_Patient 10 Ambulance arrived at 23859
# walkin_Patient 80 walk in at 23863
# walkin_Patient 80 Triage start at 23863
# walkin_Patient 80 Triage ended at 23867
# walkin_Patient 80 ED Evaluation start at 23867
# walkin_Patient 80 ED Evaluation ended at 23875
# walkin_Patient 80 CT scan at 23875
# walkin_Patient 80 CT scan ended at 23941
# walkin_Patient 80 Telestroke at 23941
# walkin_Patient 80 Telestroke ended at 23952
# walkin_Patient 80 Ambulance pre-calling contact at 23952
# walkin_Patient 80 Ambulance arrived at 23989
# EMS_Patient 11 EMS arrival at 25994
# EMS_Patient 11 CT scan at 25994
# EMS_Patient 11 CT scan ended at 25996
# EMS_Patient 11 Telestroke at 25996
# walkin_Patient 81 walk in at 26014
# walkin_Patient 81 Triage start at 26014
# walkin_Patient 81 Triage ended at 26015
# walkin_Patient 81 ED Evaluation start at 26015
# walkin_Patient 81 ED Evaluation ended at 26024
# walkin_Patient 81 CT scan at 26024
# walkin_Patient 81 CT scan ended at 26025
# walkin_Patient 81 Telestroke at 26025
# EMS_Patient 11 Telestroke ended at 26031
# EMS_Patient 11 Ambulance pre-calling contact at 26031
# EMS_Patient 11 Ambulance arrived at 26047
# walkin_Patient 81 Telestroke ended at 26053
# walkin_Patient 81 Ambulance pre-calling contact at 26053
# walkin_Patient 81 Ambulance arrived at 26059
# walkin_Patient 82 walk in at 28147
# walkin_Patient 82 Triage start at 28147
# walkin_Patient 82 Triage ended at 28147
# walkin_Patient 82 ED Evaluation start at 28147
# EMS_Patient 12 EMS arrival at 28183
# EMS_Patient 12 CT scan at 28183
# walkin_Patient 82 ED Evaluation ended at 28189
# walkin_Patient 82 CT scan at 28189
# EMS_Patient 12 CT scan ended at 28203
# EMS_Patient 12 Telestroke at 28203
# EMS_Patient 12 Telestroke ended at 28218
# EMS_Patient 12 Ambulance pre-calling contact at 28218
# EMS_Patient 12 Ambulance arrived at 28220
# walkin_Patient 82 CT scan ended at 28225
# walkin_Patient 82 Telestroke at 28225
# walkin_Patient 82 Telestroke ended at 28232
# walkin_Patient 82 Ambulance pre-calling contact at 28232
# walkin_Patient 82 Ambulance arrived at 28245
# walkin_Patient 83 walk in at 30295
# walkin_Patient 83 Triage start at 30295
# walkin_Patient 83 Triage ended at 30296
# walkin_Patient 83 ED Evaluation start at 30296
# walkin_Patient 83 ED Evaluation ended at 30300
# walkin_Patient 83 CT scan at 30300
# walkin_Patient 83 CT scan ended at 30342
# walkin_Patient 83 Telestroke at 30342
# walkin_Patient 83 Telestroke ended at 30357
# walkin_Patient 83 Ambulance pre-calling contact at 30357
# walkin_Patient 83 Ambulance arrived at 30414
# EMS_Patient 13 EMS arrival at 30423
# EMS_Patient 13 CT scan at 30423
# EMS_Patient 13 CT scan ended at 30423
# EMS_Patient 13 Telestroke at 30423
# EMS_Patient 13 Telestroke ended at 30446
# EMS_Patient 13 Ambulance pre-calling contact at 30446
# EMS_Patient 13 Ambulance arrived at 30447
# walkin_Patient 84 walk in at 32410
# walkin_Patient 84 Triage start at 32410
# walkin_Patient 84 Triage ended at 32411
# walkin_Patient 84 ED Evaluation start at 32411
# walkin_Patient 84 ED Evaluation ended at 32412
# walkin_Patient 84 CT scan at 32412
# walkin_Patient 84 CT scan ended at 32499
# walkin_Patient 84 Telestroke at 32499
# walkin_Patient 84 Telestroke ended at 32525
# walkin_Patient 84 TPA consent at 32525
# walkin_Patient 84 Ambulance pre-calling contact at 32525
# walkin_Patient 84 Ambulance arrived at 32530
# walkin_Patient 84 TPA consent ended at 32560
# walkin_Patient 84 TPA mixing at 32560
# walkin_Patient 84 TPA mixing ended and injection at 32573
# walkin_Patient 84 CTA Scan at 32573
# walkin_Patient 84 CTA Scan ended at 32580
# walkin_Patient 84 Ambulance contact at 32580
# walkin_Patient 84 Ambulance arrived at 32585
# walkin_Patient 84 Patient send to CSC at 32585
# walkin_Patient 84 DIDO: 175.92066028781846
# EMS_Patient 14 EMS arrival at 32605
# EMS_Patient 14 CT scan at 32605
# EMS_Patient 14 CT scan ended at 32608
# EMS_Patient 14 Telestroke at 32608
# EMS_Patient 14 Telestroke ended at 32643
# EMS_Patient 14 Ambulance pre-calling contact at 32643
# EMS_Patient 14 Ambulance arrived at 32644
# walkin_Patient 85 walk in at 34605
# walkin_Patient 85 Triage start at 34605
# walkin_Patient 85 Triage ended at 34605
# walkin_Patient 85 ED Evaluation start at 34605
# walkin_Patient 85 ED Evaluation ended at 34606
# walkin_Patient 85 Routine Care at 34606
# walkin_Patient 85 Routine Care ended at 34679
# walkin_Patient 85 CT scan at 34679
# walkin_Patient 85 CT scan ended at 34695
# walkin_Patient 85 Telestroke at 34695
# walkin_Patient 85 Telestroke ended at 34703
# walkin_Patient 85 Ambulance pre-calling contact at 34703
# walkin_Patient 85 Ambulance arrived at 34732
# EMS_Patient 15 EMS arrival at 34754
# EMS_Patient 15 CT scan at 34754
# EMS_Patient 15 CT scan ended at 34766
# EMS_Patient 15 Patient gets on ambulance at 34766
# EMS_Patient 15 Patient send to CSC at 34767
# EMS_Patient 15 DIDO: 13.272710331293638
# walkin_Patient 86 walk in at 36830
# walkin_Patient 86 Triage start at 36830
# walkin_Patient 86 Triage ended at 36837
# walkin_Patient 86 ED Evaluation start at 36837
# walkin_Patient 86 ED Evaluation ended at 36850
# walkin_Patient 86 CT scan at 36850
# walkin_Patient 86 CT scan ended at 36865
# walkin_Patient 86 Ambulance contact at 36865
# walkin_Patient 86 Ambulance arrived at 36871
# walkin_Patient 86 Patient send to CSC at 36871
# walkin_Patient 86 DIDO: 41.04667401438928
# EMS_Patient 16 EMS arrival at 36999
# EMS_Patient 16 CT scan at 36999
# EMS_Patient 16 CT scan ended at 37006
# EMS_Patient 16 Telestroke at 37006
# EMS_Patient 16 Telestroke ended at 37026
# EMS_Patient 16 Ambulance pre-calling contact at 37026
# EMS_Patient 16 Ambulance arrived at 37030
# walkin_Patient 87 walk in at 38980
# walkin_Patient 87 Triage start at 38980
# walkin_Patient 87 Triage ended at 38982
# walkin_Patient 87 ED Evaluation start at 38982
# walkin_Patient 87 ED Evaluation ended at 38982
# walkin_Patient 87 CT scan at 38982
# walkin_Patient 87 CT scan ended at 39066
# walkin_Patient 87 Ambulance contact at 39066
# walkin_Patient 87 Ambulance arrived at 39069
# walkin_Patient 87 Patient send to CSC at 39069
# walkin_Patient 87 DIDO: 89.65633795805479
# EMS_Patient 17 EMS arrival at 39150
# EMS_Patient 17 Triage start at 39150
# EMS_Patient 17 Triage ended at 39150
# EMS_Patient 17 ED Evaluation start at 39150
# EMS_Patient 17 ED Evaluation ended at 39167
# EMS_Patient 17 CT scan at 39167
# EMS_Patient 17 CT scan ended at 39170
# EMS_Patient 17 Telestroke at 39170
# EMS_Patient 17 Telestroke ended at 39183
# EMS_Patient 17 Ambulance pre-calling contact at 39183
# EMS_Patient 17 Ambulance arrived at 39195
# walkin_Patient 88 walk in at 41078
# walkin_Patient 88 Triage start at 41078
# walkin_Patient 88 Triage ended at 41086
# walkin_Patient 88 ED Evaluation start at 41086
# walkin_Patient 88 ED Evaluation ended at 41087
# walkin_Patient 88 CT scan at 41087
# walkin_Patient 88 CT scan ended at 41106
# walkin_Patient 88 Telestroke at 41106
# walkin_Patient 88 Telestroke ended at 41125
# walkin_Patient 88 Ambulance pre-calling contact at 41125
# walkin_Patient 88 Ambulance arrived at 41129
# EMS_Patient 18 EMS arrival at 41340
# EMS_Patient 18 Triage start at 41340
# EMS_Patient 18 Triage ended at 41358
# EMS_Patient 18 ED Evaluation start at 41358
# EMS_Patient 18 ED Evaluation ended at 41360
# EMS_Patient 18 CT scan at 41360
# EMS_Patient 18 CT scan ended at 41529
# EMS_Patient 18 Telestroke at 41529
# EMS_Patient 18 Telestroke ended at 41595
# EMS_Patient 18 Ambulance pre-calling contact at 41595
# EMS_Patient 18 Ambulance arrived at 41596
# walkin_Patient 89 walk in at 43307
# walkin_Patient 89 Triage start at 43307
# walkin_Patient 89 Triage ended at 43314
# walkin_Patient 89 ED Evaluation start at 43314
# walkin_Patient 89 ED Evaluation ended at 43314
# walkin_Patient 89 CT scan at 43314
# walkin_Patient 89 CT scan ended at 43407
# walkin_Patient 89 Telestroke at 43407
# walkin_Patient 89 Telestroke ended at 43443
# walkin_Patient 89 Ambulance pre-calling contact at 43443
# walkin_Patient 89 Ambulance arrived at 43459
# EMS_Patient 19 EMS arrival at 43539
# EMS_Patient 19 CT scan at 43539
# EMS_Patient 19 CT scan ended at 43543
# EMS_Patient 19 Telestroke at 43543
# EMS_Patient 19 Telestroke ended at 43607
# EMS_Patient 19 Ambulance pre-calling contact at 43607
# EMS_Patient 19 Ambulance arrived at 43669
# walkin_Patient 90 walk in at 45422
# walkin_Patient 90 Triage start at 45422
# walkin_Patient 90 Triage ended at 45429
# walkin_Patient 90 ED Evaluation start at 45429
# walkin_Patient 90 ED Evaluation ended at 45431
# walkin_Patient 90 CT scan at 45431
# walkin_Patient 90 CT scan ended at 45463
# walkin_Patient 90 Telestroke at 45463
# walkin_Patient 90 Telestroke ended at 45465
# walkin_Patient 90 Ambulance pre-calling contact at 45465
# walkin_Patient 90 Ambulance arrived at 45470
# EMS_Patient 20 EMS arrival at 45695
# EMS_Patient 20 CT scan at 45695
# EMS_Patient 20 CT scan ended at 45707
# EMS_Patient 20 Telestroke at 45707
# EMS_Patient 20 Telestroke ended at 45733
# EMS_Patient 20 TPA consent at 45733
# EMS_Patient 20 Ambulance pre-calling contact at 45733
# EMS_Patient 20 TPA consent ended at 45749
# EMS_Patient 20 TPA mixing at 45749
# EMS_Patient 20 Ambulance arrived at 45755
# EMS_Patient 20 TPA mixing ended and injection at 45766
# EMS_Patient 20 ICU out time: 71.69870396360784
# EMS_Patient 20 ICU at 45766
# EMS_Patient 20 ICU ended at 45805
# walkin_Patient 91 walk in at 47538
# walkin_Patient 91 Triage start at 47538
# walkin_Patient 91 Triage ended at 47541
# walkin_Patient 91 ED Evaluation start at 47541
# walkin_Patient 91 ED Evaluation ended at 47545
# walkin_Patient 91 CT scan at 47545
# walkin_Patient 91 CT scan ended at 47554
# walkin_Patient 91 Ambulance contact at 47554
# walkin_Patient 91 Ambulance arrived at 47563
# walkin_Patient 91 Patient send to CSC at 47563
# walkin_Patient 91 DIDO: 25.004567968171614
# EMS_Patient 21 EMS arrival at 47876
# EMS_Patient 21 Triage start at 47876
# EMS_Patient 21 Triage ended at 47884
# EMS_Patient 21 ED Evaluation start at 47884
# EMS_Patient 21 ED Evaluation ended at 47893
# EMS_Patient 21 CT scan at 47893
# EMS_Patient 21 CT scan ended at 47920
# EMS_Patient 21 Telestroke at 47920
# EMS_Patient 21 Telestroke ended at 47986
# EMS_Patient 21 TPA consent at 47986
# EMS_Patient 21 Ambulance pre-calling contact at 47986
# EMS_Patient 21 Ambulance arrived at 47986
# EMS_Patient 21 TPA consent ended at 48037
# EMS_Patient 21 TPA mixing at 48037
# EMS_Patient 21 TPA mixing ended and injection at 48049
# EMS_Patient 21 CTA Scan at 48049
# EMS_Patient 21 CTA Scan ended at 48136
# EMS_Patient 21 ICU out time: 260.12364098984835
# EMS_Patient 21 ICU at 48136
# EMS_Patient 21 ICU ended at 48148
# walkin_Patient 92 walk in at 49683
# walkin_Patient 92 Triage start at 49683
# walkin_Patient 92 Triage ended at 49686
# walkin_Patient 92 ED Evaluation start at 49686
# walkin_Patient 92 ED Evaluation ended at 49696
# walkin_Patient 92 Routine Care at 49696
# walkin_Patient 92 Routine Care ended at 49878
# walkin_Patient 92 CT scan at 49878
# walkin_Patient 92 CT scan ended at 49884
# walkin_Patient 92 Telestroke at 49884
# walkin_Patient 92 Telestroke ended at 49890
# walkin_Patient 92 Ambulance pre-calling contact at 49890
# walkin_Patient 92 Ambulance arrived at 49899
# EMS_Patient 22 EMS arrival at 50053
# EMS_Patient 22 CT scan at 50053
# EMS_Patient 22 CT scan ended at 50079
# EMS_Patient 22 Patient gets on ambulance at 50079
# EMS_Patient 22 Patient send to CSC at 50080
# EMS_Patient 22 DIDO: 27.39854534387996
# walkin_Patient 93 walk in at 51863
# walkin_Patient 93 Triage start at 51863
# walkin_Patient 93 Triage ended at 51864
# walkin_Patient 93 ED Evaluation start at 51864
# walkin_Patient 93 ED Evaluation ended at 51886
# walkin_Patient 93 CT scan at 51886
# walkin_Patient 93 CT scan ended at 51904
# walkin_Patient 93 Telestroke at 51904
# walkin_Patient 93 Telestroke ended at 51950
# walkin_Patient 93 Ambulance pre-calling contact at 51950
# walkin_Patient 93 Ambulance arrived at 51981
# EMS_Patient 23 EMS arrival at 52219
# EMS_Patient 23 CT scan at 52219
# EMS_Patient 23 CT scan ended at 52239
# EMS_Patient 23 Telestroke at 52239
# EMS_Patient 23 Telestroke ended at 52241
# EMS_Patient 23 Ambulance pre-calling contact at 52241
# EMS_Patient 23 Ambulance arrived at 52250
# walkin_Patient 94 walk in at 54074
# walkin_Patient 94 Triage start at 54074
# walkin_Patient 94 Triage ended at 54078
# walkin_Patient 94 ED Evaluation start at 54078
# walkin_Patient 94 ED Evaluation ended at 54081
# walkin_Patient 94 CT scan at 54081
# walkin_Patient 94 CT scan ended at 54122
# walkin_Patient 94 Telestroke at 54122
# walkin_Patient 94 Telestroke ended at 54142
# walkin_Patient 94 Ambulance pre-calling contact at 54142
# walkin_Patient 94 Ambulance arrived at 54172
# EMS_Patient 24 EMS arrival at 54358
# EMS_Patient 24 CT scan at 54358
# EMS_Patient 24 CT scan ended at 54359
# EMS_Patient 24 Telestroke at 54359
# EMS_Patient 24 Telestroke ended at 54423
# EMS_Patient 24 Ambulance pre-calling contact at 54423
# EMS_Patient 24 Ambulance arrived at 54519
# walkin_Patient 95 walk in at 56334
# walkin_Patient 95 Triage start at 56334
# walkin_Patient 95 Triage ended at 56336
# walkin_Patient 95 ED Evaluation start at 56336
# walkin_Patient 95 ED Evaluation ended at 56347
# walkin_Patient 95 CT scan at 56347
# walkin_Patient 95 CT scan ended at 56381
# walkin_Patient 95 Telestroke at 56381
# walkin_Patient 95 Telestroke ended at 56387
# walkin_Patient 95 Ambulance pre-calling contact at 56387
# walkin_Patient 95 Ambulance arrived at 56397
# EMS_Patient 25 EMS arrival at 56455
# EMS_Patient 25 CT scan at 56455
# EMS_Patient 25 CT scan ended at 56493
# EMS_Patient 25 Telestroke at 56493
# EMS_Patient 25 Telestroke ended at 56589
# EMS_Patient 25 Ambulance pre-calling contact at 56589
# EMS_Patient 25 Ambulance arrived at 56590
# walkin_Patient 96 walk in at 58517
# walkin_Patient 96 Triage start at 58517
# walkin_Patient 96 Triage ended at 58523
# walkin_Patient 96 ED Evaluation start at 58523
# walkin_Patient 96 ED Evaluation ended at 58524
# walkin_Patient 96 CT scan at 58524
# walkin_Patient 96 CT scan ended at 58527
# walkin_Patient 96 Telestroke at 58527
# walkin_Patient 96 Telestroke ended at 58569
# walkin_Patient 96 Ambulance pre-calling contact at 58569
# walkin_Patient 96 Ambulance arrived at 58576
# EMS_Patient 26 EMS arrival at 58665
# EMS_Patient 26 CT scan at 58665
# EMS_Patient 26 CT scan ended at 58732
# EMS_Patient 26 Patient gets on ambulance at 58732
# EMS_Patient 26 Patient send to CSC at 58733
# EMS_Patient 26 DIDO: 68.67778223519417
# walkin_Patient 97 walk in at 60668
# walkin_Patient 97 Triage start at 60668
# walkin_Patient 97 Triage ended at 60700
# walkin_Patient 97 ED Evaluation start at 60700
# walkin_Patient 97 ED Evaluation ended at 60701
# walkin_Patient 97 CT scan at 60701
# walkin_Patient 97 CT scan ended at 60726
# walkin_Patient 97 Ambulance contact at 60726
# walkin_Patient 97 Ambulance arrived at 60752
# walkin_Patient 97 Patient send to CSC at 60752
# walkin_Patient 97 DIDO: 84.69149177721556
# EMS_Patient 27 EMS arrival at 60774
# EMS_Patient 27 CT scan at 60774
# EMS_Patient 27 CT scan ended at 60778
# EMS_Patient 27 Patient gets on ambulance at 60778
# EMS_Patient 27 Patient send to CSC at 60779
# EMS_Patient 27 DIDO: 5.553641435923055
# walkin_Patient 98 walk in at 62864
# walkin_Patient 98 Triage start at 62864
# walkin_Patient 98 Triage ended at 62878
# walkin_Patient 98 ED Evaluation start at 62878
# walkin_Patient 98 ED Evaluation ended at 62880
# walkin_Patient 98 CT scan at 62880
# walkin_Patient 98 CT scan ended at 62897
# walkin_Patient 98 Telestroke at 62897
# walkin_Patient 98 Telestroke ended at 62899
# walkin_Patient 98 Ambulance pre-calling contact at 62899
# walkin_Patient 98 Ambulance arrived at 62900
# EMS_Patient 28 EMS arrival at 62941
# EMS_Patient 28 CT scan at 62941
# EMS_Patient 28 CT scan ended at 62945
# EMS_Patient 28 Patient gets on ambulance at 62945
# EMS_Patient 28 Patient send to CSC at 62946
# EMS_Patient 28 DIDO: 5.09062337497744
# EMS_Patient 29 EMS arrival at 65047
# EMS_Patient 29 CT scan at 65047
# walkin_Patient 99 walk in at 65070
# walkin_Patient 99 Triage start at 65070
# walkin_Patient 99 Triage ended at 65070
# walkin_Patient 99 ED Evaluation start at 65070
# walkin_Patient 99 ED Evaluation ended at 65070
# walkin_Patient 99 CT scan at 65070
# walkin_Patient 99 CT scan ended at 65083
# walkin_Patient 99 Telestroke at 65083
# walkin_Patient 99 Telestroke ended at 65083
# walkin_Patient 99 Ambulance pre-calling contact at 65083
# walkin_Patient 99 Ambulance arrived at 65093
# EMS_Patient 29 CT scan ended at 65125
# EMS_Patient 29 Telestroke at 65125
# EMS_Patient 29 Telestroke ended at 65149
# EMS_Patient 29 Ambulance pre-calling contact at 65149
# EMS_Patient 29 Ambulance arrived at 65226
# EMS_Patient 30 EMS arrival at 67211
# EMS_Patient 30 CT scan at 67211
# EMS_Patient 30 CT scan ended at 67236
# EMS_Patient 30 Telestroke at 67236
# EMS_Patient 30 Telestroke ended at 67245
# EMS_Patient 30 Ambulance pre-calling contact at 67245
# EMS_Patient 30 Ambulance arrived at 67254
# EMS_Patient 31 EMS arrival at 69273
# EMS_Patient 31 CT scan at 69273
# EMS_Patient 31 CT scan ended at 69281
# EMS_Patient 31 Telestroke at 69281
# EMS_Patient 31 Telestroke ended at 69335
# EMS_Patient 31 Ambulance pre-calling contact at 69335
# EMS_Patient 31 Ambulance arrived at 69347
# EMS_Patient 32 EMS arrival at 71458
# EMS_Patient 32 CT scan at 71458
# EMS_Patient 32 CT scan ended at 71463
# EMS_Patient 32 Telestroke at 71463
# EMS_Patient 32 Telestroke ended at 71477
# EMS_Patient 32 Ambulance pre-calling contact at 71477
# EMS_Patient 32 Ambulance arrived at 71483
# EMS_Patient 33 EMS arrival at 73631
# EMS_Patient 33 CT scan at 73631
# EMS_Patient 33 CT scan ended at 73670
# EMS_Patient 33 Telestroke at 73670
# EMS_Patient 33 Telestroke ended at 73693
# EMS_Patient 33 Ambulance pre-calling contact at 73693
# EMS_Patient 33 Ambulance arrived at 73705
# EMS_Patient 34 EMS arrival at 75779
# EMS_Patient 34 CT scan at 75779
# EMS_Patient 34 CT scan ended at 75837
# EMS_Patient 34 Telestroke at 75837
# EMS_Patient 34 Telestroke ended at 75890
# EMS_Patient 34 Ambulance pre-calling contact at 75890
# EMS_Patient 34 Ambulance arrived at 75916
# EMS_Patient 35 EMS arrival at 77892
# EMS_Patient 35 CT scan at 77892
# EMS_Patient 35 CT scan ended at 77904
# EMS_Patient 35 Telestroke at 77904
# EMS_Patient 35 Telestroke ended at 77905
# EMS_Patient 35 Ambulance pre-calling contact at 77905
# EMS_Patient 35 Ambulance arrived at 77909
# EMS_Patient 36 EMS arrival at 80072
# EMS_Patient 36 CT scan at 80072
# EMS_Patient 36 CT scan ended at 80137
# EMS_Patient 36 Telestroke at 80137
# EMS_Patient 36 Telestroke ended at 80142
# EMS_Patient 36 Ambulance pre-calling contact at 80142
# EMS_Patient 36 Ambulance arrived at 80143
# EMS_Patient 37 EMS arrival at 82194
# EMS_Patient 37 CT scan at 82194
# EMS_Patient 37 CT scan ended at 82236
# EMS_Patient 37 Telestroke at 82236
# EMS_Patient 37 Telestroke ended at 82246
# EMS_Patient 37 Ambulance pre-calling contact at 82246
# EMS_Patient 37 Ambulance arrived at 82247
# EMS_Patient 38 EMS arrival at 84364
# EMS_Patient 38 CT scan at 84364
# EMS_Patient 38 CT scan ended at 84405
# EMS_Patient 38 Telestroke at 84405
# EMS_Patient 38 Telestroke ended at 84408
# EMS_Patient 38 Ambulance pre-calling contact at 84408
# EMS_Patient 38 Ambulance arrived at 84411
# EMS_Patient 39 EMS arrival at 86458
# EMS_Patient 39 CT scan at 86458
# EMS_Patient 39 CT scan ended at 86482
# EMS_Patient 39 Telestroke at 86482
# EMS_Patient 39 Telestroke ended at 86492
# EMS_Patient 39 Ambulance pre-calling contact at 86492
# EMS_Patient 39 Ambulance arrived at 86594
# EMS_Patient 40 EMS arrival at 88707
# EMS_Patient 40 CT scan at 88707
# EMS_Patient 40 CT scan ended at 88755
# EMS_Patient 40 Telestroke at 88755
# EMS_Patient 40 Telestroke ended at 88772
# EMS_Patient 40 Ambulance pre-calling contact at 88772
# EMS_Patient 40 Ambulance arrived at 88774
# EMS_Patient 41 EMS arrival at 90836
# EMS_Patient 41 CT scan at 90836
# EMS_Patient 41 CT scan ended at 90854
# EMS_Patient 41 Patient gets on ambulance at 90854
# EMS_Patient 41 Patient send to CSC at 90855
# EMS_Patient 41 DIDO: 19.31138847184775
# EMS_Patient 42 EMS arrival at 92951
# EMS_Patient 42 CT scan at 92951
# EMS_Patient 42 CT scan ended at 92998
# EMS_Patient 42 Telestroke at 92998
# EMS_Patient 42 Telestroke ended at 93000
# EMS_Patient 42 Ambulance pre-calling contact at 93000
# EMS_Patient 42 Ambulance arrived at 93023
# EMS_Patient 43 EMS arrival at 95102
# EMS_Patient 43 CT scan at 95102
# EMS_Patient 43 CT scan ended at 95105
# EMS_Patient 43 Telestroke at 95105
# EMS_Patient 43 Telestroke ended at 95142
# EMS_Patient 43 Ambulance pre-calling contact at 95142
# EMS_Patient 43 Ambulance arrived at 95148
# EMS_Patient 44 EMS arrival at 97376
# EMS_Patient 44 Triage start at 97376
# EMS_Patient 44 Triage ended at 97392
# EMS_Patient 44 ED Evaluation start at 97392
# EMS_Patient 44 ED Evaluation ended at 97411
# EMS_Patient 44 CT scan at 97411
# EMS_Patient 44 CT scan ended at 97433
# EMS_Patient 44 Telestroke at 97433
# EMS_Patient 44 Telestroke ended at 97450
# EMS_Patient 44 Ambulance pre-calling contact at 97450
# EMS_Patient 44 Ambulance arrived at 97454
# EMS_Patient 45 EMS arrival at 99582
# EMS_Patient 45 CT scan at 99582
# EMS_Patient 45 CT scan ended at 99618
# EMS_Patient 45 Telestroke at 99618
# EMS_Patient 45 Telestroke ended at 99660
# EMS_Patient 45 Ambulance pre-calling contact at 99660
# EMS_Patient 45 Ambulance arrived at 99660
# EMS_Patient 46 EMS arrival at 101761
# EMS_Patient 46 CT scan at 101761
# EMS_Patient 46 CT scan ended at 101820
# EMS_Patient 46 Telestroke at 101820
# EMS_Patient 46 Telestroke ended at 101881
# EMS_Patient 46 Ambulance pre-calling contact at 101881
# EMS_Patient 46 Ambulance arrived at 101927
# EMS_Patient 47 EMS arrival at 103915
# EMS_Patient 47 CT scan at 103915
# EMS_Patient 47 CT scan ended at 103925
# EMS_Patient 47 Telestroke at 103925
# EMS_Patient 47 Telestroke ended at 103928
# EMS_Patient 47 Ambulance pre-calling contact at 103928
# EMS_Patient 47 Ambulance arrived at 103946
# EMS_Patient 48 EMS arrival at 106120
# EMS_Patient 48 CT scan at 106120
# EMS_Patient 48 CT scan ended at 106138
# EMS_Patient 48 Telestroke at 106138
# EMS_Patient 48 Telestroke ended at 106152
# EMS_Patient 48 Ambulance pre-calling contact at 106152
# EMS_Patient 48 Ambulance arrived at 106154
# EMS_Patient 49 EMS arrival at 108281
# EMS_Patient 49 CT scan at 108281
# EMS_Patient 49 CT scan ended at 108296
# EMS_Patient 49 Telestroke at 108296
# EMS_Patient 49 Telestroke ended at 108297
# EMS_Patient 49 Ambulance pre-calling contact at 108297
# EMS_Patient 49 Ambulance arrived at 108313
# EMS_Patient 50 EMS arrival at 110398
# EMS_Patient 50 CT scan at 110398
# EMS_Patient 50 CT scan ended at 110456
# EMS_Patient 50 Telestroke at 110456
# EMS_Patient 50 Telestroke ended at 110474
# EMS_Patient 50 TPA consent at 110474
# EMS_Patient 50 Ambulance pre-calling contact at 110474
# EMS_Patient 50 TPA consent ended at 110493
# EMS_Patient 50 TPA mixing at 110493
# EMS_Patient 50 Ambulance arrived at 110505
# EMS_Patient 50 TPA mixing ended and injection at 110506
# EMS_Patient 50 ICU out time: 108.11231073696399
# EMS_Patient 50 ICU at 110506
# EMS_Patient 50 ICU ended at 110586
# EMS_Patient 51 EMS arrival at 112599
# EMS_Patient 51 Triage start at 112599
# EMS_Patient 51 Triage ended at 112599
# EMS_Patient 51 ED Evaluation start at 112599
# EMS_Patient 51 ED Evaluation ended at 112624
# EMS_Patient 51 CT scan at 112624
# EMS_Patient 51 CT scan ended at 112648
# EMS_Patient 51 Telestroke at 112648
# EMS_Patient 51 Telestroke ended at 112668
# EMS_Patient 51 Ambulance pre-calling contact at 112668
# EMS_Patient 51 Ambulance arrived at 112673
# EMS_Patient 52 EMS arrival at 114737
# EMS_Patient 52 CT scan at 114737
# EMS_Patient 52 CT scan ended at 114742
# EMS_Patient 52 Telestroke at 114742
# EMS_Patient 52 Telestroke ended at 114790
# EMS_Patient 52 Ambulance pre-calling contact at 114790
# EMS_Patient 52 Ambulance arrived at 114812
# EMS_Patient 53 EMS arrival at 116926
# EMS_Patient 53 CT scan at 116926
# EMS_Patient 53 CT scan ended at 116973
# EMS_Patient 53 Telestroke at 116973
# EMS_Patient 53 Telestroke ended at 117046
# EMS_Patient 53 Ambulance pre-calling contact at 117046
# EMS_Patient 53 Ambulance arrived at 117075
# EMS_Patient 54 EMS arrival at 119134
# EMS_Patient 54 Triage start at 119134
# EMS_Patient 54 Triage ended at 119152
# EMS_Patient 54 ED Evaluation start at 119152
# EMS_Patient 54 ED Evaluation ended at 119157
# EMS_Patient 54 CT scan at 119157
# EMS_Patient 54 CT scan ended at 119211
# EMS_Patient 54 Telestroke at 119211
# EMS_Patient 54 Telestroke ended at 119219
# EMS_Patient 54 Ambulance pre-calling contact at 119219
# EMS_Patient 54 Ambulance arrived at 119257
# EMS_Patient 55 EMS arrival at 121275
# EMS_Patient 55 CT scan at 121275
# EMS_Patient 55 CT scan ended at 121309
# EMS_Patient 55 Telestroke at 121309
# EMS_Patient 55 Telestroke ended at 121312
# EMS_Patient 55 Ambulance pre-calling contact at 121312
# EMS_Patient 55 Ambulance arrived at 121340
# EMS_Patient 56 EMS arrival at 123448
# EMS_Patient 56 CT scan at 123448
# EMS_Patient 56 CT scan ended at 123486
# EMS_Patient 56 Telestroke at 123486
# EMS_Patient 56 Telestroke ended at 123500
# EMS_Patient 56 Ambulance pre-calling contact at 123500
# EMS_Patient 56 Ambulance arrived at 123501
# EMS_Patient 57 EMS arrival at 125516
# EMS_Patient 57 CT scan at 125516
# EMS_Patient 57 CT scan ended at 125644
# EMS_Patient 57 Telestroke at 125644
# EMS_Patient 57 Telestroke ended at 125649
# EMS_Patient 57 Ambulance pre-calling contact at 125649
# EMS_Patient 57 Ambulance arrived at 125665
# EMS_Patient 58 EMS arrival at 127692
# EMS_Patient 58 CT scan at 127692
# EMS_Patient 58 CT scan ended at 127697
# EMS_Patient 58 Telestroke at 127697
# EMS_Patient 58 Telestroke ended at 127728
# EMS_Patient 58 Ambulance pre-calling contact at 127728
# EMS_Patient 58 Ambulance arrived at 127744
# EMS_Patient 59 EMS arrival at 129842
# EMS_Patient 59 CT scan at 129842
# EMS_Patient 59 CT scan ended at 129873
# EMS_Patient 59 Patient gets on ambulance at 129873
# EMS_Patient 59 Patient send to CSC at 129874
# EMS_Patient 59 DIDO: 32.26452707772842
# EMS_Patient 60 EMS arrival at 132033
# EMS_Patient 60 CT scan at 132033
# EMS_Patient 60 CT scan ended at 132052
# EMS_Patient 60 Telestroke at 132052
# EMS_Patient 60 Telestroke ended at 132057
# EMS_Patient 60 Ambulance pre-calling contact at 132057
# EMS_Patient 60 Ambulance arrived at 132081
# EMS_Patient 61 EMS arrival at 134185
# EMS_Patient 61 CT scan at 134185
# EMS_Patient 61 CT scan ended at 134186
# EMS_Patient 61 Telestroke at 134186
# EMS_Patient 61 Telestroke ended at 134226
# EMS_Patient 61 Ambulance pre-calling contact at 134226
# EMS_Patient 61 Ambulance arrived at 134230
# EMS_Patient 62 EMS arrival at 136364
# EMS_Patient 62 CT scan at 136364
# EMS_Patient 62 CT scan ended at 136372
# EMS_Patient 62 Telestroke at 136372
# EMS_Patient 62 Telestroke ended at 136428
# EMS_Patient 62 Ambulance pre-calling contact at 136428
# EMS_Patient 62 Ambulance arrived at 136439
# EMS_Patient 63 EMS arrival at 138500
# EMS_Patient 63 CT scan at 138500
# EMS_Patient 63 CT scan ended at 138503
# EMS_Patient 63 Telestroke at 138503
# EMS_Patient 63 Telestroke ended at 138525
# EMS_Patient 63 Ambulance contact at 138525
# EMS_Patient 63 Ambulance pre-calling contact at 138525
# EMS_Patient 63 Ambulance arrived at 138540
# EMS_Patient 63 Patient send to CSC at 138540
# EMS_Patient 63 DIDO: 40.55232717390754
# EMS_Patient 63 Ambulance arrived at 138540
# EMS_Patient 64 EMS arrival at 140821
# EMS_Patient 64 CT scan at 140821
# EMS_Patient 64 CT scan ended at 140846
# EMS_Patient 64 Telestroke at 140846
# EMS_Patient 64 Telestroke ended at 140861
# EMS_Patient 64 Ambulance pre-calling contact at 140861
# EMS_Patient 64 Ambulance arrived at 140870
# EMS_Patient 65 EMS arrival at 143075
# EMS_Patient 65 CT scan at 143075
# EMS_Patient 65 CT scan ended at 143080
# EMS_Patient 65 Patient gets on ambulance at 143080
# EMS_Patient 65 Patient send to CSC at 143081
# EMS_Patient 65 DIDO: 6.177592987602111
# EMS_Patient 66 EMS arrival at 145302
# EMS_Patient 66 Triage start at 145302
# EMS_Patient 66 Triage ended at 145306
# EMS_Patient 66 ED Evaluation start at 145306
# EMS_Patient 66 ED Evaluation ended at 145308
# EMS_Patient 66 CT scan at 145308
# EMS_Patient 66 CT scan ended at 145309
# EMS_Patient 66 Telestroke at 145309
# EMS_Patient 66 Telestroke ended at 145310
# EMS_Patient 66 Ambulance pre-calling contact at 145310
# EMS_Patient 66 Ambulance arrived at 145312
# EMS_Patient 67 EMS arrival at 147431
# EMS_Patient 67 CT scan at 147431
# EMS_Patient 67 CT scan ended at 147438
# EMS_Patient 67 Telestroke at 147438
# EMS_Patient 67 Telestroke ended at 147456
# EMS_Patient 67 Ambulance pre-calling contact at 147456
# EMS_Patient 67 Ambulance arrived at 147460
# EMS_Patient 68 EMS arrival at 149636
# EMS_Patient 68 CT scan at 149636
# EMS_Patient 68 CT scan ended at 149654
# EMS_Patient 68 Telestroke at 149654
# EMS_Patient 68 Telestroke ended at 149686
# EMS_Patient 68 TPA consent at 149686
# EMS_Patient 68 Ambulance pre-calling contact at 149686
# EMS_Patient 68 TPA consent ended at 149690
# EMS_Patient 68 TPA mixing at 149690
# EMS_Patient 68 TPA mixing ended and injection at 149706
# EMS_Patient 68 Patient send to CSC at 149706
# EMS_Patient 68 DIDO: 70.84496482499526
# EMS_Patient 68 Ambulance arrived at 149747
# EMS_Patient 69 EMS arrival at 151786
# EMS_Patient 69 CT scan at 151786
# EMS_Patient 69 CT scan ended at 151869
# EMS_Patient 69 Telestroke at 151869
# EMS_Patient 69 Telestroke ended at 151904
# EMS_Patient 69 Ambulance pre-calling contact at 151904
# EMS_Patient 69 Ambulance arrived at 151905
#
# CSC number of patients sent: 17 (17 percent)
# Mean DIDO time: 44.06559593295715 minutes
# ICU number of patients sent: 3 (3 percent)
# Mean ICU out time 43.52343293271406 minutes
#
# Mean HS DIDO time: 32.985512755253595 minutes (14 patients)
# Mean IS DIDO time: 123.38281255640686 minutes (2 patients)
# Mean door-to-needle time: 117.43874325030046 minutes (5 patients)
